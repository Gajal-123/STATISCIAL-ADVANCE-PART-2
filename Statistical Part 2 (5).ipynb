# %% [markdown]
# #### Statistics Part 2

# %% [markdown]
# 1.  What is hypothesis testing in statistics?
#     -
#     Hypothesis testing is a statistical method used to make decisions or inferences about a population based on sample data. It helps determine whether the evidence from the data is strong enough to support or reject a claim (called a hypothesis) about the population.
#
#  Key Concepts in Hypothesis Testing:
#
#  1.Null Hypothesis (H0)
#  - The default or original claim.
#
#  - Usually states “no effect” or “no difference”.
#
#  - Example: H0: The mean exam score is equal to 70.
#
#  2.Alternative Hypothesis (H1 or Ha)
#  - The competing claim you're trying to prove.
#
#  - It states there is an effect, change, or difference.
#
#  - Example: Ha: The mean exam score is not equal to 70.
#
#  3.Test Statistic
#  - A numerical value calculated from sample data, used to test the hypothesis.
#
#  - Example: Z-score, t-score, chi-square, etc.
#
#  4.Significance Level (α)
#  - The probability of rejecting the null hypothesis when it's actually true (Type I error).
#
#  - Common values: 0.05, 0.01, or 0.10.
#
#  5.p-value
#  - The probability of obtaining a test statistic as extreme as the one observed, assuming H0is true.
#
#  - If p-value ≤ α, reject H0 ; otherwise, fail to reject H0
#
# #####  Steps in Hypothesis Testing:
#
# | Step | Description                                     |
# | ---- | ----------------------------------------------- |
# | 1.   | State the null and alternative hypotheses       |
# | 2.   | Choose a significance level ($\alpha$)          |
# | 3.   | Collect data and calculate the test statistic   |
# | 4.   | Find the p-value or critical value              |
# | 5.   | Make a decision: reject or fail to reject $H_0$ |
# | 6.   | State the conclusion in context                 |
#
# -> Example:
#
# You want to test whether a new drug improves recovery time compared to the standard drug.
#  - H0: New drug has no effect on recovery time.
#  - Ha: New drug reduces recovery time
#
# After analysis:
#
#  - You find a p-value = 0.03
#  - Significance level = 0.05
#
# Since 0.03<0.05, you reject H0 → There is significant evidence that the new drug helps.
#
#
# | Term                               | Meaning                                    |
# | ---------------------------------- | ------------------------------------------ |
# | **Hypothesis Testing**             | Decision-making process using sample data  |
# | **Null Hypothesis** ($H_0$)        | No effect or no difference                 |
# | **Alternative Hypothesis** ($H_a$) | What you’re trying to prove                |
# | **p-value**                        | Probability of observed result under $H_0$ |
# | **Conclusion**                     | Reject or fail to reject $H_0$             |

# %% [markdown]
# 2.  What is the null hypothesis, and how does it differ from the alternative hypothesis?
#     -
#     In hypothesis testing, the null hypothesis and the alternative hypothesis are two competing statements about a population parameter. These form the basis for making statistical decisions using sample data.
#
# Null Hypothesis (H0):
#  - It represents the default, status quo, or no-effect assumption.
#
#  - It assumes that any observed differences or effects in the sample data are due to random chance.
#
#  - The null hypothesis is the one we test against and attempt to disprove.
#
# -> Examples:
#  - H0 : The population mean is equal to 50.
#  - H0 : There is no difference between two treatments.
#  - H0 : The coin is fair (P=0.5).
#
#
# Alternative Hypothesis (Ha or H1 ):
#  - This is the opposite of the null hypothesis.
#
#  - It represents the statement we want to test for or prove.
#
#  - It suggests that the observed effect is real and significant, not just due to chance.
#
# -> Examples:
#  - Ha : The population mean is not equal to 50.
#  - Ha : There is a difference between two treatments.
#  - Ha : The coin is biased (𝑃≠0.5).
#
#
# ##### Key Differences:
#
# | Feature               | Null Hypothesis ($H_0$)                       | Alternative Hypothesis ($H_a$)            |
# | --------------------- | --------------------------------------------- | ----------------------------------------- |
# | **Purpose**           | Assumed true unless proven otherwise          | What you seek to provide evidence for     |
# | **Represents**        | No change, no effect, status quo              | A new effect, difference, or relationship |
# | **Decision Based On** | p-value vs. significance level ($\alpha$)     | Rejected if $p \leq \alpha$               |
# | **Mathematical Form** | Usually includes **equality** (e.g., =, ≥, ≤) | Usually includes **inequality** (≠, <, >) |
#
#
# ##### Example: Testing a New Drug
#
# | Hypothesis | Statement                                                    |
# | ---------- | ------------------------------------------------------------ |
# | $H_0$      | The new drug has **no effect** (mean recovery time = 5 days) |
# | $H_a$      | The new drug **reduces recovery time** (mean < 5 days)       |

# %% [markdown]
# 3.  What is the significance level in hypothesis testing, and why is it important?
#     -
#     The significance level (denoted by α, alpha) is a threshold value used in hypothesis testing to decide whether to reject the null hypothesis.
#
# -> Definition:
#
# The significance level is the probability of making a Type I error, which means:
#
#  - Rejecting the null hypothesis H0 when it is actually true.
#
# ##### Common Values of α:
# | α (Significance Level) | Meaning                                |
# | ---------------------- | -------------------------------------- |
# | 0.05                   | 5% risk of incorrectly rejecting $H_0$ |
# | 0.01                   | 1% risk (more strict)                  |
# | 0.10                   | 10% risk (more lenient)                |
#
#
# ##### Why It’s Important:
# | Reason                                     | Explanation                                                                    |
# | ------------------------------------------ | ------------------------------------------------------------------------------ |
# | **Controls error rate**                    | It sets the maximum acceptable probability of a false positive (Type I error). |
# | **Guides decision-making**                 | If the p-value ≤ α, you reject $H_0$; otherwise, you fail to reject it.        |
# | **Determines strength of evidence needed** | Lower α means **stronger evidence** is required to reject $H_0$.               |
# | **Reflects risk tolerance**                | Higher α = more risk of error; lower α = more caution.                         |
#
#
# Example:
# You are testing if a new teaching method improves scores.
#  - H0: Mean score = 70
#  - Ha: Mean score ≠ 70
#  - α = 0.05
#
# You calculate a p-value = 0.03
#
# Since 0.03<0.05, you reject H0 and conclude the method does have an effect.
#
# -> Caution:
#  - Choosing α too high (e.g., 0.10) increases the chance of false positives, while too low (e.g., 0.01) may make it too hard to detect real effects.
#
# | Term                       | Meaning                                                               |
# | -------------------------- | --------------------------------------------------------------------- |
# | **Significance level (α)** | The cutoff for deciding whether a result is statistically significant |
# | **Role**                   | Limits the probability of incorrectly rejecting the null hypothesis   |
# | **Typical values**         | 0.05 (most common), 0.01 (stricter), 0.10 (more lenient)              |

# %% [markdown]
# 4.  What does a P-value represent in hypothesis testing?
#     -
#     The P-value is a key concept in hypothesis testing. It measures the probability of observing the sample results, or something more extreme, assuming the null hypothesis is true.
#
#  - Definition:
# The P-value is the probability of getting a result as extreme as (or more extreme than) the observed result by random chance alone, if the null hypothesis (H0) is true.
#
# ##### How to Interpret a P-value:
# | **P-value**                      | **Interpretation**                                                       |
# | -------------------------------- | ------------------------------------------------------------------------ |
# | **Small P-value** (e.g., ≤ 0.05) | **Strong evidence** against $H_0$ → **Reject** the null hypothesis       |
# | **Large P-value** (e.g., > 0.05) | **Weak evidence** against $H_0$ → **Fail to reject** the null hypothesis |
#
# Example:
#
# You test whether a coin is fair.
#  - H0: The coin is fair (P=0.5)
#  - You flip it 10 times and get 9 heads.
#
# You calculate a P-value = 0.02
#
# With a significance level α = 0.05:
#
#  - Since 0.02 < 0.05, you reject H0.
#  - Conclusion: There's strong evidence the coin is not fair.
#
#
# ##### Important Notes:
#  - A small P-value means your data is unlikely under the null hypothesis.
#
#  - A large P-value doesn’t prove H0 is true — it just means there's not enough evidence to reject it.
#
#  - The P-value does not give the probability that H0 is true or false.
#
#
# ##### In Summary:
#
# | Term             | Meaning                                                                         |
# | ---------------- | ------------------------------------------------------------------------------- |
# | **P-value**      | Probability of the observed result (or more extreme) occurring if $H_0$ is true |
# | **Used for**     | Comparing with significance level (α) to decide whether to reject $H_0$         |
# | **Low P-value**  | Strong evidence against $H_0$                                                   |
# | **High P-value** | Weak evidence; do not reject $H_0$                                              |

# %% [markdown]
# 5.  How do you interpret the P-value in hypothesis testing?
#     -
#     The P-value helps you determine the strength of evidence against the null hypothesis (H0) in a hypothesis test. It tells you how likely it is to observe your sample data (or something more extreme), assuming that the null hypothesis is true.
#
# #####  Interpretation Rule:
# | **P-value** compared to α | **Decision**                         | **Interpretation**                                            |
# | ------------------------- | ------------------------------------ | ------------------------------------------------------------- |
# | **P ≤ α**                 | **Reject** the null hypothesis $H_0$ | There is **statistically significant** evidence against $H_0$ |
# | **P > α**                 | **Fail to reject** $H_0$             | There is **not enough evidence** to reject $H_0$              |
#
# #####  Example (with α = 0.05):
# | **P-value** | **Interpretation**                          |
# | ----------- | ------------------------------------------- |
# | 0.03        | Reject $H_0$; strong evidence against it    |
# | 0.07        | Fail to reject $H_0$; insufficient evidence |
# | 0.001       | Very strong evidence against $H_0$          |
# | 0.49        | Very weak evidence against $H_0$            |
#
#  What the P-value Tells You:
#  - A small P-value (e.g., 0.01) → The observed result is unlikely under H0 → Evidence against H0
#
#  - A large P-value (e.g., 0.60) → The observed result is likely under H0 → No reason to reject H0
#
#  Misinterpretation to Avoid:
#  - P-value is NOT the probability that the null hypothesis is true.
#  - P-value is NOT the chance of making a mistake.
#  - P-value is the probability of your data, given H0 is true.
#
# | Term               | Meaning                                                              |
# | ------------------ | -------------------------------------------------------------------- |
# | **P-value**        | Probability of observing the data (or more extreme) if $H_0$ is true |
# | **Small P-value**  | Evidence **against** $H_0$ → **Reject** it                           |
# | **Large P-value**  | Not enough evidence → **Fail to reject** $H_0$                       |
# | **Compare with α** | Determines your decision threshold                                   |

# %% [markdown]
# 6.  What are Type 1 and Type 2 errors in hypothesis testing?
#     -
#     In hypothesis testing, Type I and Type II errors represent two kinds of incorrect conclusions that can occur when making decisions based on sample data.
#
#
# ##### Type I Error (False Positive):
#
#  - Definition: Rejecting the null hypothesis (H0) when it is actually true.
#
#  - It means you conclude there is an effect or difference when there isn’t.
#
#  - Denoted by: α (alpha) — the significance level.
#
#  - Example: Saying a drug works when it actually doesn't.
#
#
# ##### Type II Error (False Negative):
#
#  - Definition: Failing to reject the null hypothesis (H0) when it is actually false.
#
#  - It means you conclude there is no effect, when there actually is one.
#
#  - Denoted by: β (beta) — the probability of Type II error.
#
#  - Example: Saying a drug doesn't work when it actually does.
#
#
# ##### Comparison Table:\
# | **Error Type**  | **What happens**                     | **Truth**               | **Decision**   | **Consequence**                      |
# | --------------- | ------------------------------------ | ----------------------- | -------------- | ------------------------------------ |
# | **Type I (α)**  | Reject $H_0$ when it’s true          | $H_0$ is actually true  | False positive | You detect an effect that isn’t real |
# | **Type II (β)** | Fail to reject $H_0$ when it’s false | $H_0$ is actually false | False negative | You miss detecting a real effect     |
#
#
# ##### Visualization Summary:
# |                          | **Reality: $H_0$ is True** | **Reality: $H_0$ is False** |
# | ------------------------ | -------------------------- | --------------------------- |
# | **Reject $H_0$**         | **Type I Error (α)**       | ✅ Correct Decision          |
# | **Fail to Reject $H_0$** | ✅ Correct Decision         | **Type II Error (β)**       |
#
#
# -> Key Point:
#
# You cannot eliminate both errors, so:
#
#  - Lowering α reduces Type I error risk, but may increase Type II error.
#  - A good balance is important and depends on the context (e.g., medicine vs. marketing).
#
#
# | Error       | Meaning                                            | Symbol | Goal                          |
# | ----------- | -------------------------------------------------- | ------ | ----------------------------- |
# | **Type I**  | False alarm (rejecting a true $H_0$)               | α      | Keep it low (e.g., 0.05)      |
# | **Type II** | Missed detection (failing to reject a false $H_0$) | β      | Minimize with good test power |

# %% [markdown]
# 7.  What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#     -
#     In hypothesis testing, whether you use a one-tailed or two-tailed test depends on the direction of the effect you’re testing for. The difference lies in how you set up the alternative hypothesis and where you check for statistical significance on the distribution curve.
#
# -> One-Tailed Test:
#  - Tests for a difference in one specific direction (either greater than or less than).
#  - Used when the research question clearly states a direction of interest.
#
#  Examples:
#  - H0: μ = 100
#
#  - Ha: μ > 100 (Right-tailed test)
#            or
#  - Ha: μ < 100 (Left-tailed test)
#
# Diagram:
#  - Area of rejection is on one side (tail) of the distribution.
#
#
# -> Two-Tailed Test:
#  - Tests for a difference in either direction (not equal to).
#  - Used when the research question does not specify a direction.
#
# Example:
#  - H0: μ = 100
#  - Ha: μ ≠ 100
#
# Diagram:
#  - Area of rejection is split between both tails of the distribution (upper and lower).
#
# #####  Comparison Table:
# | Feature                    | **One-Tailed Test**                       | **Two-Tailed Test**                              |
# | -------------------------- | ----------------------------------------- | ------------------------------------------------ |
# | **Alternative Hypothesis** | Directional (e.g., μ > μ₀ or μ < μ₀)      | Non-directional (e.g., μ ≠ μ₀)                   |
# | **Rejection Region**       | One tail of the distribution              | Both tails of the distribution                   |
# | **When to Use**            | You are only interested in one direction  | You are interested in any significant difference |
# | **P-value**                | Area in one tail                          | Area split across both tails                     |
# | **More powerful?**         | More powerful **if** direction is correct | More conservative (harder to reject $H_0$)       |
#
#
# ##### Example Situation:
#  1.One-tailed:
#  - A company claims their battery lasts more than 10 hours.
#    - H0: μ = 10
#    - Ha: μ > 10 (Right-tailed)
#
#  2.Two-tailed:
#  - A researcher tests if a new teaching method results in any change in test scores.
#    - H0: μ = 75
#    - Ha: μ ≠ 75 (Two-tailed)
#
# | Test Type      | Hypothesis Structure        | Checks For                         |
# | -------------- | --------------------------- | ---------------------------------- |
# | **One-tailed** | $H_a: μ > μ_0$ or $μ < μ_0$ | Difference in **one direction**    |
# | **Two-tailed** | $H_a: μ ≠ μ_0$              | Difference in **either direction** |

# %% [markdown]
# 8.  What is the Z-test, and when is it used in hypothesis testing?
#     -
#     The Z-test is a statistical test used to determine whether there is a significant difference between sample data and a population parameter, or between two sample means — when the population standard deviation is known and the sample size is sufficiently large.
#
# ##### When to Use a Z-test:
#
# | Condition                                        | Explanation                                                            |
# | ------------------------------------------------ | ---------------------------------------------------------------------- |
# | ✅ **Population standard deviation (σ) is known** | This is essential for using Z-tests.                                   |
# | ✅ **Sample size is large** (n ≥ 30)              | For small samples, use **t-tests** instead.                            |
# | ✅ **Data is approximately normally distributed** | Or the sample size is large enough for Central Limit Theorem to apply. |
#
#
# ##### Common Types of Z-tests:
# | Type of Z-Test             | Use Case                                            |
# | -------------------------- | --------------------------------------------------- |
# | **One-sample Z-test**      | Compare sample mean to population mean              |
# | **Two-sample Z-test**      | Compare two sample means (from independent samples) |
# | **Z-test for proportions** | Compare sample proportion to population proportion  |
#
#
# ##### Z-test Formula (One-sample):
# Z=x−μ  / σ/n
#
# Where:
#
# ˉ
# x = sample mean
#
# μ = population mean
#
# σ = population standard deviation
#
# n = sample size
#
#
#  Example:
#
# A machine is supposed to fill bottles with 500 ml of juice.
#  - Known σ = 10 ml
#  - Sample mean = 495 ml
#  - Sample size = 36
#
# Z = 495−500 / 10/36 = -5 / 10/6 = -3.0
#
#  - Compare the Z-score to the critical Z-value (e.g., ±1.96 for 95% confidence) to decide if you reject H0.
#
#
# | Feature        | Z-test                                          |
# | -------------- | ----------------------------------------------- |
# | **Used when**  | σ is known, sample size is large (n ≥ 30)       |
# | **Purpose**    | Test hypotheses about means or proportions      |
# | **Statistic**  | Z-score (based on standard normal distribution) |
# | **Compare to** | Z-critical value or p-value                     |

# %% [markdown]
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing?
#     -
#     A Z-score (or standard score) tells you how many standard deviations a data point or sample statistic is from the population mean.
#
#  - In hypothesis testing, the Z-score helps determine how extreme your sample result is under the null hypothesis.
#
# #####  Z-score Formula (for a sample mean):
# Z= x −μ / σ/ n
#
# Where:
#
# ˉ
# x = sample mean
#
# μ = population mean under H0
#
# σ = population standard deviation
#
# n = sample size
#
#
# ##### Steps to Calculate Z-score in Hypothesis Testing:
#
#  1.State the hypotheses:
#
# 𝐻0:𝜇 =𝜇0,
#
# 𝐻𝑎:𝜇≠,,>,<μ0
#
#  2.Calculate sample meanˉx
#
#  3.Use known population standard deviation (σ)
#
#  4.Plug into the formula to find Z
#
#
# -> Example:
#
# Let’s say:
#
#  - Population mean (μ) = 100
#
#  - Population standard deviation (σ) = 10
#
#  - Sample mean (ˉx) = 104
#
#  - Sample size (n) = 25
#
# Z= 104−100 / 10/25 = 4/2 =2.0
#
#  - So, the Z-score is 2.0, meaning the sample mean is 2 standard deviations above the population mean.
#
#
# -> What Does the Z-score Represent?
#
#  - It shows how far (in standard deviation units) your observed value is from the expected value under H0
#
#  - The larger the absolute Z-score, the less likely the result occurred by chance.
#
#  - You compare it with critical Z-values (e.g., ±1.96 for 95% confidence) or find the p-value from a Z-table.
#
#
# | Term               | Meaning                                                           |   |                                   |
# | ------------------ | ----------------------------------------------------------------- | - | --------------------------------- |
# | **Z-score**        | Number of standard deviations a value is from the population mean |   |                                   |
# | **Used for**       | Measuring how unusual your sample result is under $H_0$           |   |                                   |
# | **Interpretation** | Large                                                             | Z | → stronger evidence against $H_0$ |

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#     -
#     The T-distribution (or Student’s T-distribution) is a probability distribution used in statistics to estimate population parameters when the sample size is small and/or the population standard deviation is unknown.
#
# It is similar in shape to the normal distribution, but has heavier tails, which account for the additional uncertainty from estimating the standard deviation from the sample.
#
# #####  Key Characteristics of the T-distribution:
# | Feature                                | Description                                                           |
# | -------------------------------------- | --------------------------------------------------------------------- |
# | **Bell-shaped**                        | Like the normal distribution                                          |
# | **Symmetrical**                        | Centered at 0                                                         |
# | **Heavier tails**                      | More probability in the tails (accounts for small sample uncertainty) |
# | **Depends on degrees of freedom (df)** | As sample size increases, it approaches the normal distribution       |
#
#
# ##### When to Use T-distribution Instead of Normal Distribution:
# | Situation                                   | Use T-distribution if…                                        |
# | ------------------------------------------- | ------------------------------------------------------------- |
# | ✅ **Small sample size**                     | Sample size $n < 30$                                          |
# | ✅ **Population standard deviation unknown** | You use **sample standard deviation (s)** instead of $\sigma$ |
# | ✅ **Assuming approximate normality**        | Population is approximately normal or sample is large enough  |
#
#
# -> Example:
#
# Let’s say you’re testing the average height of students in a class:
#  - Sample size = 12
#  - Sample mean = 168 cm
#  - Sample standard deviation s=5 cm
#  - Population standard deviation σ is unknown
#
# Use the T-distribution because:
#  - Small sample size
#  - You don’t know the population standard deviation
#
#
# ##### T-score Formula (similar to Z):
#      𝑡 = 𝑥−𝜇 / 𝑠/𝑛
#
# Where:
#
#    ˉ
#  - x = sample mean
#
#  - μ = population mean (under H0)
#
#  - s = sample standard deviation
#
#  - n = sample size
#
#  - Degrees of freedom = df=n−1
#
#
# | Feature                  | **Normal Distribution**       | **T-distribution**               |
# | ------------------------ | ----------------------------- | -------------------------------- |
# | Known population std dev |  Yes                          | No (uses sample std dev)         |
# | Sample size              | Large (typically $n \geq 30$) | Small ($n < 30$)                 |
# | Shape                    | Thinner tails                 | Heavier tails (more uncertainty) |
# | Degrees of freedom (df)  | Not required                  | Required: $df = n - 1$           |
# | Use for...               | Z-tests                       | T-tests                          |

# %% [markdown]
# 11.  What is the difference between a Z-test and a T-test?
#      -
#      The Z-test and T-test are both used in hypothesis testing to determine if there is a significant difference between means. The key difference lies in what you know about the population and the sample size.
#
#
# ##### Z-test vs. T-test:
#
# | Feature                               | **Z-test**                                                                            | **T-test**                                                                  |
# | ------------------------------------- | ------------------------------------------------------------------------------------- | --------------------------------------------------------------------------- |
# | **Population Standard Deviation (σ)** | **Known**                                                                             | **Unknown**                                                                 |
# | **Sample Size**                       | **Large (n ≥ 30)**                                                                    | **Small (n < 30)**                                                          |
# | **Distribution Used**                 | **Standard Normal Distribution (Z-distribution)**                                     | **T-distribution**                                                          |
# | **Shape of Distribution**             | Bell-shaped (fixed)                                                                   | Bell-shaped with **heavier tails** (depends on degrees of freedom)          |
# | **Formula**                           | $Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}$                                         | $t = \frac{\bar{x} - \mu}{s / \sqrt{n}}$                                    |
# | **Common Use Cases**                  | - Comparing a sample mean to a population mean (σ known)   <br> - Proportions testing | - Comparing sample mean to population (σ unknown) <br> - Small sample sizes |
# | **Degrees of Freedom (df)**           | Not required                                                                          | Required: $df = n - 1$                                                      |
#
#  When to Use Each Test:
#  - Use a Z-test when:
#    - The population standard deviation is known.
#    - You have a large sample size (n ≥ 30).
#
#  - Use a T-test when:
#    - The population standard deviation is unknown.
#    - You have a small sample size (n < 30).
#    - You're using the sample standard deviation.
#
#
# -> Example:
#
#  1.Z-test example:
#  - Population std dev is known: σ = 5
#  - Sample size = 40
#  - Use Z-test to compare the sample mean to the population mean
#
#  2.T-test example:
#  - Population std dev is unknown
#  - Sample size = 15
#  - Use T-test and sample std dev s in the formula
#
#
# | Situation                 | **Use** |
# | ------------------------- | ------- |
# | Large sample & σ known    | Z-test  |
# | Small sample or σ unknown | T-test  ||

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#     -
#     A T-test is a statistical test used to determine whether there is a significant difference between means — either between a sample mean and a population mean, or between two sample means — when the population standard deviation is unknown and/or the sample size is small (n < 30).
#
# It uses the T-distribution, which adjusts for the uncertainty introduced by estimating the population standard deviation from the sample.
#
# ##### Types of T-tests:
#
# | Type                                | Use Case                                                                        |
# | ----------------------------------- | ------------------------------------------------------------------------------- |
# | **One-sample T-test**               | Compare a sample mean to a known population mean                                |
# | **Two-sample T-test (independent)** | Compare means of two independent groups                                         |
# | **Paired-sample T-test**            | Compare means from the **same group at two time points** (e.g., before & after) |
#
# ##### T-score Formula (One-sample T-test):
#
# t= x−μ / s/n
#
# Where:
#
# ˉ
# x = sample mean
#
# μ = population mean under H0
#
# s = sample standard deviation
#
# n = sample size
#
# Degrees of freedom = df=n−1
#
#
# -> Steps in Using a T-test in Hypothesis Testing:
#
#  1.State the hypotheses:
#
#  - H0: There is no difference (e.g., μ=μ0)
#  - Ha: There is a difference (e.g., 𝜇≠𝜇0)
#
#  2.Choose significance level: Typically α = 0.05
#
#  3.Calculate the t-score using the formula above
#
#  4.Determine the critical t-value from the t-distribution table based on your degrees of freedom (df)
#
#  5.Compare your calculated t-score to the critical t-value:
#
# If ∣t∣ > t critical, reject the null hypothesis
#
# Otherwise, fail to reject the null hypothesis
#
#
# Example:
#
# A teacher believes that students study an average of 6 hours/week. A sample of 10 students gives:
#
#  - Mean = 5.2 hours
#
#  - Sample std dev = 1.5 hours
#
#  - n=10
#          𝑡=5.2−6 / 1.5/10 = −0.8/0.474≈−1.69
#  - Check this t-score against the critical value at df=9. If it exceeds it in magnitude, you reject H0.
#
#
# | Feature               | T-test                                                                   |
# | --------------------- | ------------------------------------------------------------------------ |
# | **Purpose**           | Compare means when σ is unknown                                          |
# | **Distribution used** | T-distribution                                                           |
# | **When to use**       | Small samples, unknown population standard deviation                     |
# | **Result**            | A t-score, which you compare to critical values or use to find a p-value |

# %% [markdown]
# 13.  What is the relationship between Z-test and T-test in hypothesis testing?
#      -
#      The Z-test and T-test are both inferential statistical methods used in hypothesis testing to determine whether a sample mean significantly differs from a known value (or from another sample). They are closely related in purpose but differ in the conditions under which they are used.
#
# ##### Similarities Between Z-test and T-test:
# | Aspect               | Description                                                                          |
# | -------------------- | ------------------------------------------------------------------------------------ |
# | **Purpose**          | Both test hypotheses about means (or proportions)                                    |
# | **Basis**            | Both compare observed sample data to what is expected under the null hypothesis      |
# | **Structure**        | Both calculate a test statistic (Z or t) using a similar formula                     |
# | **Decision Rule**    | Both use critical values or p-values to decide whether to reject the null hypothesis |
# | **Hypothesis types** | Support both **one-tailed** and **two-tailed** tests                                 |
#
#
# #####  Key Differences:
# | Feature                                      | **Z-test**                                    | **T-test**                                     |
# | -------------------------------------------- | --------------------------------------------- | ---------------------------------------------- |
# | **Population standard deviation ($\sigma$)** | Known                                         | Unknown (estimated using sample std. dev.)     |
# | **Sample size**                              | Large (typically $n \geq 30$)                 | Small ($n < 30$)                               |
# | **Distribution used**                        | Standard normal distribution (Z)              | T-distribution (depends on degrees of freedom) |
# | **Shape of distribution**                    | Fixed, thinner tails                          | Varies with sample size, heavier tails         |
# | **Test statistic formula**                   | $Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}$ | $t = \frac{\bar{x} - \mu}{s / \sqrt{n}}$       |
#
#
# -> Relationship Overview:
#
#  - Same fundamental goal: Test if a mean difference is statistically significant.
#
#  - T-test is a generalization of the Z-test:
#    - When the sample size is large, or as degrees of freedom increase,
#      the t-distribution approaches the normal distribution,
#      making the t-test behave like a Z-test.
#
#  - Z-test is a special case of the t-test when σ is known.

# %% [markdown]
# 14.  What is a confidence interval, and how is it used to interpret statistical results?
#      -
#      A confidence interval (CI) is a range of values derived from sample data that's used to estimate an unknown population parameter—such as a mean, proportion, or difference between groups. Unlike a point estimate (e.g., “average = 50”), a CI gives both an estimate and a sense of how much uncertainty surrounds it.
#
#  - A point estimate (e.g., sample mean)
#  - A margin of error (critical value × standard error)
#  - A chosen confidence level (commonly 90%, 95%, or 99%)
#
# ##### How It’s Calculated
#
#  1.Point estimate: the statistic from your sample (mean, proportion, etc.).
#
#  2.Standard error (SE): measures variability of the estimate—e.g. sample SD divided by √n .
#
#  3.Critical value: from a Z or t distribution based on your confidence level (for 95% using z ≈ 1.96)
#
#  4.Construct CI:
#
#        Point estimate±(critical value×SE)
#
# Example: A sample mean of 35, SE = 1, and 95% confidence → CI = 35 ± 1.96 → [33.04, 36.96].
#
#
# ##### What It Actually Means
#  - A 95% CI doesn’t mean there's a 95% probability that this interval contains the true value. The true parameter is fixed—either it's in the interval or not.
#
#  - Instead, it means: if we repeated this study many times, about 95% of those intervals would include the true parameter.
#
# Common intuitive summary: “We’re 95% confident the true value lies between L and U.”
#
# ##### Why It's Useful
#  - Quantifies uncertainty: Wider CI → less precision; narrower CI → more precise estimate.
#
#  - Assesses statistical significance:
#
#    - If a CI for a difference excludes 0, the effect is statistically significant at that confidence level.
#
#    - If it includes 0, it may not be significant.
#
#  - Gives range of plausible values: More informative than just “significant/not significant.”
#
#
# ##### Key Points
#  - Higher confidence levels (like 99%) yield wider intervals, trading precision for certainty.
#
#  - The CI reflects the reliability of the estimation method, not the probability distribution of the true parameter.
#
#
# ##### Best Practice Interpretation
# • When reporting:
#
# “At the 95% confidence level, we estimate the [parameter] is between [L] and [U]. Because the interval excludes [null], the result is statistically significant.”
# • Use CI to understand both the strength of the effect and the uncertainty around it.
#
#
# ##### Common Misinterpretations
#  - "There’s a 95% chance the true mean is in this interval." (Wrong; the interval is fixed once computed.)
#
#  - "95% of the data lie within this interval." (Wrong; it's about the parameter, not data distribution.)
#
#  - "This CI is a prediction for individual outcomes." (Wrong; that would be a prediction interval.)

# %% [markdown]
# 15.  What is the margin of error, and how does it affect the confidence interval?
#      -
#      The margin of error (MoE) is the “± ” value added to your point estimate that forms the confidence interval. It quantifies the maximum expected difference between your sample statistic (like a mean or proportion) and the true population parameter, at a given confidence level.
#
#  1.How to Compute the Margin of Error
#
# MoE=(Critical value)×(Standard error)
#
#  - Critical value depends on confidence level (e.g., ~1.96 for 95%, ~2.58 for 99%) .
#
#  - Standard error (SE) is the sample standard deviation divided by √n (for proportions, √[p(1−p)/n]).
#
# Example: Sample mean = 50, SE = 1, at 95% confidence → MoE = 1.96 × 1 = 1.96.
#
#
#  2.MoE’s Role in the Confidence Interval
#
# Armed with the MoE, the CI is:
#
# Point estimate±MoE
#
# With the example above:
#
#             CI = 50 ± 1.96 → [48.04, 51.96]
# Key points:
#
#  - A smaller MoE leads to a narrower and more precise CI.
#
#  - A larger MoE produces a wider CI, signaling less precision.
# These depend on sample size, variability, and confidence level.
#
#
#  3.What Affects the Margin of Error
#  - Sample Size (n):
#
#    - Larger n → smaller SE → smaller MoE → tighter CI .
#    - Halving MoE requires quadrupling the sample size .
#
#  - *Variability (σ or p(1−p))**:
#    - More variable data → larger SE → larger MoE
#
#  - Confidence Level:
#    - Higher confidence (e.g., 99%) → larger critical value → larger MoE → wider CI.
#
#
#  4.Why It Matters
#  - Precision: MoE is a direct measure of how tightly your estimate pins down the true value.
#
#  - Decision-making: Helps determine if an observed effect is statistically meaningful; e.g., if a difference CI excludes 0, it’s significant.
#
#  - Resource planning: Guides how many respondents are needed to achieve a desired MoE.
#
#
#  5.Common Misinterpretations
#  - The MoE only reflects random sampling error, not systematic biases like nonresponse or measurement issues .
#
#  - It's not directly probabilistic—it’s about your method's accuracy over repeated samples, not a single instance.
#
#
# -> TL;DR
#  - Margin of error = critical value × standard error.
#  - It determines how wide your confidence interval is.
#  - Smaller MoE = more precision; larger MoE = less precision.
#  - Influenced by sample size, data variability, and confidence level.

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#     -
#     Bayes’ Theorem is a cornerstone of statistical inference used to update our beliefs about an uncertain event based on new evidence. It's expressed as:
#
#         P(A∣B)=P(B∣A)×P(A) / P(B)
#
# Where:
#
#  - P(A) is the prior probability of hypothesis A.
#
#  - P(B∣A) is the likelihood—the chance of observing evidence B if A is true.
#
#  - P(B) is the overall probability of observing B.
#
#  - P(A∣B) is the posterior probability—our updated belief in A after seeing B.
#
#
# -> Why It's Important in Statistics
#
#  - Reverses conditional logic: Converts P(B∣A), which is often easier to find, into what we truly want, P(A∣B) .
#  - Forms the foundation of Bayesian inference: Enables combining prior knowledge and new data to continually refine probability estimates.
#
#
# ##### -> Key Applications
#
#  - Medical diagnostics: Calculates probability of disease given symptoms/test results. E.g., even if a test is positive, if the disease is rare, actual likelihood may remain low .
#
#  - Spam filtering: Estimates the probability an email is spam based on word frequencies learned from past messages
#
#  - Machine learning: Underpins Naive Bayes classifiers—widely used in text categorization, sentiment analysis, etc.
#
#  - Decision-making under uncertainty: In business, marketing, finance—Bayesian tools update risk models and strengthen predictive insights
#
#  - Navigation & robotics: Real-time sensor data is used to update understanding of position or environment.
#
#
# #####  Significance
#  - Incorporates prior knowledge: Captures expert insight or historical data into probabilistic models.
#
#  - Dynamic updating: New data continuously refines beliefs, making it ideal for evolving systems.
#
#  - Rich interpretability: Posterior probabilities align with intuitive statements like "There's X% chance A is true after seeing B."
#
#  - Coherent framework: Maintains logical consistency in handling uncertainty, following established probability rules.
#
#
# ##### How It Works – A Simple Example
#
# Imagine a rare disease with prevalence P(Disease)=1%. A test correctly detects it 99% of the time, but gives a false positive 5% of the time.
#
# Using Bayes:
#
#  - Prior = 0.01
#
#  - Likelihood P(Positive∣Disease)=0.99
#
#  - False positive P(Positive∣No Disease)=0.05
#
#  - Evidence P(Positive)=0.99∗0.01+0.05∗0.99=0.0594
#
# Posterior: 0.99∗0.01/0.0594≈0.167 → only ~16.7% chance of disease given a positive [[similar to examples]]

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#     -
#     The chi-square distribution (χ²) is a continuous probability distribution derived from the sum of squared standard normal variables. If Z1, Z2,...Zk are independent and each follows a standard normal distribution, then:
#
#     χ k2​ =Z 12​ +Z 22​ +...+Z k2​
#
#  - Here, k represents the degrees of freedom and controls the distribution’s shape, which is skewed to the right and becomes more symmetric as k increases.
#
# ##### When is it used?
#  1.Testing independence in contingency tables:
#  - Checks if two categorical variables are related using Pearson’s chi-square test
#
#  2.Goodness-of-fit tests:
#  - Assesses whether observed category frequencies align with a theoretical distribution via the χ² test statistic.
#
#                        χ2 =∑(O i​ −E i​) / Ei
#
#  3.Testing a variance:
#  - Infers about a normal population’s variance or standard deviation using its sampling distribution
#
#  4.Framework in larger tests:
#  - Forms the foundation for other statistics—like F‑tests and likelihood‑ratio tests—thanks to its ties with normal distributions
#
#  5.Log-rank tests, Wald tests, and other inference
#  - Appears in survival analysis and model comparison tests.
#
#
# ##### Key Characteristics
#  - Support: Only non-negative values (χ² ≥ 0).
#
#  - Shape: Right-skewed for low df; becomes more symmetric as df increases, nearing normality by df ≥ 90
#
#  - Mean and variance:
#
#   Mean=𝑘, Variance=2𝑘
#
#
# ##### When to use it
#  - Large sample categorical data: Ideal for counts in contingency tables. For small samples (e.g., small expected cell counts), methods like Fisher’s exact test or Yates’s correction may be more appropriate.
#
#  - Comparing variances: When the original data are normally distributed, the χ² distribution helps test hypotheses about variance or construct confidence intervals.
#
#  - Derived statistics: Appears in F-tests (variance ratio tests), likelihood-ratio tests, and more—making it a pillar in classical hypothesis testing frameworks.
#
#
#
# | Aspect              | Description                                              |
# | ------------------- | -------------------------------------------------------- |
# | **Definition**      | Sum of squares of $k$ independent standard normals       |
# | **Parameter**       | Degrees of freedom ($k$), which shapes distribution      |
# | **Range**           | 0 to ∞                                                   |
# | **Mean & Variance** | Mean = $k$, Variance = $2k$                              |
# | **Used for**        | Categorical tests, variance inference, model comparisons |
# | **Shape**           | Right-skewed; approaches normal as $k$ grows             |

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#     -
#     The Chi-square goodness‑of‑fit test (a specific form of Pearson’s chi-square test) is a hypothesis test used with one categorical variable. It evaluates whether the observed frequencies in your sample significantly deviate from the expected frequencies based on a specified distribution (like equal proportions, or a theoretical model such as Poisson).
#
#  1.When to Use It
#
# Use this test when:
#  - You have a single categorical variable with two or more categories.
#  - You have a hypothesized distribution for its proportions (equal or non‑equal).
#  - Your sample is random, and each expected count is at least 5 for the chi-square approximation to hold.
#
#
#  2.Hypotheses
#  - Null (H₀): The observed data follow the specified distribution (e.g., p₁ = p₂ = … or match theoretical proportions).
#  - Alternative (Hₐ): At least one category's proportion deviates from expectations.
#
#
#  3.Test Statistic
#
# Calculate:
#                𝜒2=∑𝑖=1𝑘(𝑂𝑖−𝐸𝑖)2𝐸𝑖
#
#  - Oi: observed count in category i
#
#  - Ei: expected count under H₀ (e.g., n×p i)
#
#  - Degrees of freedom = k−1 (or minus the number of estimated parameters).
#
#
#  4.Decision Rule
#
#  - Determine the p-value by comparing χ² to its chi-square distribution tail.
#
#  - Reject H₀ if p-value < α (commonly 0.05), suggesting a poor fit between observed data and the expected distribution.
#
#  - Fail to reject H₀ if p-value ≥ α, indicating no strong evidence against the specified distribution.
#
#
#  5.Example: Fair Dice Test
#
# Suppose you roll a die 60 times and observe: 10, 5, 12, 8, 15, 10 for faces 1–6.
#  - H₀: each face has equal probability (10 expected per face).
#  - Compute χ² = Σ[(O_i – 10)²/10] = sum of six terms.
#  - Compare the statistic with χ² distribution for df = 5.
#  - A small p-value (e.g., <0.05) indicates the die may be biased.
#
#
#  6.Key Points
#  - Works with categorical data—not suitable for continuous data (unless binned).
#
#  - Expected counts ≥ 5 is crucial for reliability.
#
#  - Tests fit to any discrete distribution (e.g., genetic ratios, Poisson, normal if binned).
#
#  - Often simpler and less powerful than specialized tests like Kolmogorov–Smirnov or Anderson–Darling for continuous distributions.
#
#  7.Steps to Apply
#  - Define categories and hypothesize expected proportions.
#
#  - Collect data and tally observed counts Oi.
#
#  - Compute expected counts Ei=n×pi.
#
#  - Calculate χ² statistic.
#
#  - Determine degrees of freedom.
#
#  - Find p-value via chi-square distribution.
#
#  - Draw conclusion about fit and report results, including χ², df, and p-value.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#     -
#     The F-distribution (or Fisher–Snedecor distribution) is a continuous probability distribution defined for positive values, shaped by two parameters—the numerator and denominator degrees of freedom—reflecting the ratio of scaled chi-square variables:
#
#               F= U1/d1 / U2/d2
#  - where U1 and U2 are independent chi-square variables with d1 and d2 degrees of freedom, respectively.
#
#  1.Purpose & Hypothesis Testing
#
# The F-distribution serves as the null distribution for the F-statistic, which is structured as a ratio of two variances or sums of squares . It is fundamental in:
#
# a) Comparing Two Variances
#  - An F-test checks if two normally distributed populations have equal variances:
#
#                  F= s21 / s22
#
#   with 𝑑1=𝑛1−1=𝑑2=𝑛2−1
#  - If F is unusually large or small (based on tail direction), it suggests unequal variances.
#
#  - Note: sensitive to non-normality; alternatives like Levene’s test may be preferred.
#
#
# b) Analysis of Variance (ANOVA)
# Used to test if group means differ across 3+ groups, by comparing between-group vs within-group variance:
#
#           F= MSbetween / MSwithin
#  - where MS = mean squares (sum of squares ÷ df)
#
#  - Rejecting H₀ (equal means) occurs when F exceeds the critical threshold.
#
#
# c) Regression & Model Comparison
#  - In multivariate regression, the F-distribution tests if the model explains significantly more variance than expected by chance.
#
#  - Also used in likelihood ratio tests comparing nested models.
#
#
#
#  2.Key Properties
#  - Defined on (0,∞), always right-skewed, becoming more symmetric with larger df .
#  - Dependent on two degrees of freedom parameters:
#    - d1: numerator (e.g. between‑group df)
#    - d2: denominator (e.g. within‑group df)
#
#
#  3.When to Use It
#  | Scenario                    | Use Case                                            |
# | --------------------------- | --------------------------------------------------- |
# | Two-sample variance test    | Compare whether $\sigma_1^2 = \sigma_2^2$           |
# | One-way ANOVA               | Evaluate if **three or more means** are equal       |
# | Regression model assessment | Test whether model explains variance significantly  |
# | Nested model comparison     | Compare models via variance explained (e.g., in ML) |
#
#
#  4.Example: One-Way ANOVA
#
# Suppose you test three diet plans with recovery-time data:
#  - Calculate between-group sum of squares and mean square (df = 2).
#  - Calculate within-group mean square (df = total N − 3).
#  - Compute F= MSbetween / MSwithin
# Compare to critical F2,N−3; if F>F crit, reject H₀ → means differ.
#
#
#  5.Why It Matters
#  - Rigorous variance comparison: Common critical step before t‑tests or regression.
#
#  - Detects mean differences across multiple groups via ANOVA.
#
#  - Provides a coherent, distribution-based decision framework in classical statistics.
#
#  - Bridges to related distributions:
#    - F is ratio of two χ² variables, and
#    - F = t² when comparing two group means

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#     -
#     An ANOVA (Analysis of Variance) is a statistical method used to test whether three or more group means are equal by comparing:
#
#  - Between-group variance (differences in group means)
#
#  - Within-group variance (natural variability inside each group)
# Using the F-distribution, ANOVA yields an F-statistic assessing if the between-group variance is unusually large compared to within-group variance.
#
#
#  1.When to Use ANOVA
#  - One-way ANOVA: Compare means across k independent groups (k ≥ 3).
#
#  - Two-way ANOVA: Examine effects of two categorical factors and their interaction.
#
#  - Extensions: Includes factorial designs, repeated-measures ANOVA, ANCOVA, mixed models.
#
#
#  2.How ANOVA Works
#  - Null hypothesis (H₀): All group population means are equal.
#
#  - Calculate:
#    - SS_between / df_between = mean square between
#    - SS_within / df_within = mean square within
#    - F-statistic = MS_between ÷ MS_within
#
#  - Decision: If F is large (p-value < α), reject H₀ → means differ.
#
#
#  3.Key Assumptions of ANOVA
#
# ANOVA relies on these critical assumptions:
#
#  - Independence: Observations (and residuals) are independent; one observation doesn't affect another
#
#  - Normality: Residuals (or group-level data) should follow a normal distribution; moderate deviations are tolerated with larger or balanced samples
#
#  - Homoscedasticity: Variance across groups is equal. Testable via Levene’s or similar; ANOVA is robust if group sizes are equal and variance
#    ratios < 3–4
#
#  - Measurement level: Dependent variable must be continuous (interval/ratio); independent variables are categorical.
#
#  - (For repeated-measures) Sphericity: Variances of pairwise differences are equal; violations require corrections.
#
#
#  4.When Assumptions Fail
#  - Independence violations are critical—use different designs instead (e.g., repeated measures).
#
#  - Normality: With large, balanced groups, ANOVA remains robust; for severe departures, consider transformations or non-parametric alternatives.
#
#  - Unequal variances: If groups are unbalanced or variance ratio > 4, use Welch’s ANOVA or adjust via robust methods.
#
#
#  5.Post-hoc Testing
#  - ANOVA only tells if there's a difference—not which groups differ. If significant, use post-hoc tests (Tukey HSD, Bonferroni, Scheffé) to identify pairwise differences while controlling the Type I error rate.
#
#
# | Aspect               | Description                                                 |
# | -------------------- | ----------------------------------------------------------- |
# | **Goal**             | Compare means of ≥3 groups                                  |
# | **Underlying logic** | Between-group variance test using F-statistic               |
# | **Key assumptions**  | Independence, normality, equal variances, measurement level |
# | **Outputs**          | F-statistic, p-value; if p < α, follow with post-hoc tests  |
# | **Extensions**       | Two-way ANOVA, repeated measures, ANCOVA, mixed models      |

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#     -
#     Here are the main types of ANOVA, each tailored to different experimental designs:
#
#  1.One‑Way ANOVA
#
#  - Definition: Tests differences in means across three or more independent groups based on a single factor
#  - Use case: One categorical factor (e.g., teaching method) affecting a continuous outcome (e.g., test scores)
#  - Degrees of freedom: df_between = k‑1, df_within = n‑k.
#
#  2.Two‑Way (Factorial) ANOVA
#
#  - Definition: Examines the effects of two factors and their interaction, with data from independent groups
#  - Use case: E.g., analyzing how teaching method and gender jointly influence performance.
#
#  3.Repeated‑Measures (Within‑Subjects) ANOVA
#
#  - Definition: Measures the same subjects under multiple conditions or timepoints
#  - Use case: Evaluating cholesterol levels at 1, 3, and 6 months post-intervention
#
#  4.Two‑Way Repeated‑Measures ANOVA (or Mixed ANOVA)
#  - Definition: Combines repeated within-subjects and between-subjects factors—can also be fully within-subjects if all factors are repeated
#  - Use case: Studying how pain relief varies over time (within) by treatment type (between)
#
#  5.Factorial ANOVA (3‑Way and Beyond)
#  - Definition: Extends the model to multiple factors (three or more), allowing study of all main effects and interactions
#  - Use case: Investigating plant growth with variables like fertilizer type, sunlight, and water levels
#
#  6.MANOVA (Multivariate ANOVA)
#  - Definition: Tests effects of factors on multiple correlated outcome variables simultaneously
#  - Use case: Assessing how therapy method influences both stress and anxiety scores
#
#  7.ANCOVA (Analysis of Covariance)
#  - Definition: Combines ANOVA with covariates to adjust for continuous control variables
#  - Use case: Comparing teaching methods while adjusting for students' baseline IQ
#
#
# -> Non‑Parametric Alternatives:
#
#  - Use these when normality or equal variances don’t hold:
#  - Kruskal–Wallis test: Non-parametric equivalent of one-way ANOVA
#  - Friedman test: Non-parametric counterpart to one-way repeated-measures ANOVA
#  - Scheirer–Ray–Hare test: Non-parametric version of multi-factor ANOVA.
#
#
# | Type                           | Factors                      | Subjects      | Outcome type        |
# | ------------------------------ | ---------------------------- | ------------- | ------------------- |
# | One‑Way ANOVA                  | 1 categorical                | Independent   | Continuous          |
# | Two‑Way / Factorial ANOVA      | 2+ categorical               | Independent   | Continuous          |
# | Repeated‑Measures ANOVA        | 1 categorical (repeated)     | Same subjects | Continuous          |
# | Two‑Way Repeated / Mixed ANOVA | Mixed within & between       | Mixed groups  | Continuous          |
# | MANOVA                         | Multiple dependent variables | Independent   | Multiple continuous |
# | ANCOVA                         | Includes covariates          | Independent   | Continuous          |
#
#
# -> Key Considerations:
#
#  - Assumptions: Independence, normality, and equal variances (or sphericity for repeated measures)
#  - Post-hoc analysis: Required when overall ANOVA is significant (e.g., Tukey HSD)
#  - Non-parametric alternatives: Kruskal–Wallis, Friedman, etc., when assumptions are violated

# %% [markdown]
# 22.  What is the F-test, and how does it relate to hypothesis testing?
#      -
#      The F-test is a family of statistical tests that use the F-distribution to compare ratios of variances. It’s pivotal in many hypothesis-testing scenarios where you're looking at variability across groups or models.
#
#  1.Core Idea
#
# At its core, the F-statistic is:
#
#         𝐹 = variance estimate1 / variance estimate2
#
# -> This could mean:
#  - A ratio of two sample variances (to check if two population variances are equal)
#  - A comparison of mean squares in ANOVA (between‑group vs. within‑group variance)
#  - A test of regression model significance, comparing model fit relative to error.
#
#
#  2.Common Uses of the F‑test
#
# a) Comparing Two Variances
#
# Goal: test if σ₁² = σ₂²
#  - H₀: variances equal; Hₐ: not equal (two-tailed) or directional
#  - Compute F = s₁² / s₂², compare to F-critical or assess p-value.
#
# b) ANOVA (Analysis of Variance)
#
# Goal: test if all group means are equal
#  - F = (between-group variance) / (within-group variance)
#  - A high F and small p-value indicate at least one mean differs
#
# c) Regression/Model Comparisons
#
# Goal: test whether predictors significantly explain variance
#
#  - F quantifies if a model performs significantly better than a simpler model (like intercept-only)
#  - A “goodness-of-fit” test for the whole regression.
#
#
#  3.Hypothesis Testing Steps
#  - Set Hypotheses
#    - For variance test: H₀: σ₁² = σ₂²
#    - For ANOVA: H₀: µ₁ = µ₂ = …
#    - For regression: H₀: all βᵢ = 0
#
#  - Compute F Stat = ratio of variances or mean squares.
#
#  - Determine p‑value or compare F to critical value based on df₁ (numerator) and df₂ (denominator).
#
#  - Decision:
#    - Reject H₀ if F is extreme (high or low, based on context) and p-value < α.
#
#  4.Why It Matters
#  - Tests equality of variances: important assumption check before t-tests or ANOVA .
#  - Foundation for ANOVA: assesses differences across multiple groups in one coherent test .
#  - Whole-model significance: in regression, tells you if your predictors together explain more than random noise.
#
#
#  5.In Everyday Terms
#
# “The F-test is a goodness of fit test in linear regression... it basically tests if your model is different from a model containing only the intercept term.”
#
# “The F-statistic is a ratio between your treatment/model/predictors effect and everything that your treatment didn't explain (error). The higher the F value, the higher the effect of your treatment is.”
#
# That means, when F is large, the explained variance outweighs the unexplained—signifying a meaningful effect.
#
#
#  6.Quick Reference Table
#
# | Scenario          | Test Statistic                          | Null Hypothesis | df₁, df₂                     |
# | ----------------- | --------------------------------------- | --------------- | ---------------------------- |
# | **Two variances** | F = s₁² / s₂²                           | σ₁² = σ₂²       | df₁ = n₁−1, df₂ = n₂−1       |
# | **One-way ANOVA** | F = MS\_between / MS\_within            | All µᵢ equal    | df₁ = k−1, df₂ = N−k         |
# | **Regression**    | F = (RSS₁−RSS₂)/(p₂−p₁) ÷ (RSS₂/(n−p₂)) | All βᵢ = 0      | df based on model complexity |

# %% [markdown]
# ### Practical Part - 1

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.
#    -
#    Here's a simple Python program to generate a random variable and display its value using the built-in random module:

# %%
import random

# Generate a random floating-point number between 0.0 and 1.0
:contentReference[oaicite:1]{index=1}
:contentReference[oaicite:2]{index=2}

# Generate a random integer between 1 and 10 (inclusive)
:contentReference[oaicite:3]{index=3}
:contentReference[oaicite:4]{index=4}

# %%
#Choose a random item from a list:

items = ['apple', 'banana', 'cherry']
choice = random.choice(items)
print("Random choice:", choice)

# %%
#Draw multiple unique samples (e.g., 3 items from 10):

sample = random.sample(range(1, 11), 3)
print("Random sample of 3 unique ints from 1–10:", sample)

# %% [markdown]
# -> Summary
#  - Use random.random() for floats in [0, 1).
#  - Use random.randint(a, b) for integers in [a, b].
#  - Use random.uniform(a, b) for floats in [a, b].
#  - Use random.choice() and random.sample() for sampling from sequences.
#
# Let me know if you'd like to explore generating random numbers from specific distributions, seeding for reproducibility, or using libraries like numpy!

# %% [markdown]
# 2.  Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
#     -
#     Here's how to generate a discrete uniform distribution in Python and plot its Probability Mass Function (PMF):

# %%
import numpy as np
from scipy.stats import randint
import matplotlib.pyplot as plt

# 1. Define the range [a, b] for integers
:contentReference[oaicite:2]{index=2}

# 2. Create a discrete uniform random variable X ~ U{a, …, b}
:contentReference[oaicite:3]{index=3} :contentReference[oaicite:4]{index=4}

# 3. Compute the PMF values at each integer
:contentReference[oaicite:5]{index=5}
:contentReference[oaicite:6]{index=6}

# 4. Plot the PMF using markers and vertical lines
:contentReference[oaicite:7]{index=7}
:contentReference[oaicite:8]{index=8}
:contentReference[oaicite:9]{index=9}
:contentReference[oaicite:10]{index=10}
:contentReference[oaicite:11]{index=11}
:contentReference[oaicite:12]{index=12}
:contentReference[oaicite:13]{index=13}
:contentReference[oaicite:14]{index=14}
:contentReference[oaicite:15]{index=15}
plt.show()

# %% [markdown]
# What Happens Here:
#  - randint(a, b+1) gives a discrete uniform random variable over integers a..b
#  - X.pmf(x) returns the probability P(X=x) for each integer — all equal to 1/(b–a+1).
#  - We plot using markers ('bo') and vertical lines (vlines) to create a clear PMF visualization.

# %% [markdown]
# #### Optional: Visualizing Sample Frequencies
#  - To confirm the PMF through simulation:

# %%
# Simulate draws
:contentReference[oaicite:21]{index=21}

# Empirical relative frequencies
:contentReference[oaicite:22]{index=22}
:contentReference[oaicite:23]{index=23}

# Overlay empirical bars
:contentReference[oaicite:24]{index=24}
:contentReference[oaicite:25]{index=25}
:contentReference[oaicite:26]{index=26}
:contentReference[oaicite:27]{index=27}
:contentReference[oaicite:28]{index=28}
plt.legend()
plt.show()

# %% [markdown]
#  Notes & Citations
#  - randint from scipy.stats models a discrete uniform variable over integers
#  - PMF for each integer is constant and equal to 1/(b−a+1) .
#  - Plotting with markers + vertical lines is a clear way to visualize a PMF

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
#    -
#    Here’s a simple Python function that calculates (and optionally demonstrates) the probability mass function (PMF) of a Bernoulli distribution for a single trial with success probability p:

# %%
def bernoulli_pmf(k, p):
    """
    Compute the PMF of a Bernoulli distribution.
    
    Parameters:
    - k: int, the outcome (0 = failure, 1 = success)
    - p: float, probability of success (0 ≤ p ≤ 1)
    
    Returns:
    - float: probability of observing outcome k
    """
    if k == 1:
        return p
    elif k == 0:
        return 1 - p
    else:
        raise ValueError("k must be 0 or 1")

# Example usage
:contentReference[oaicite:1]{index=1}
:contentReference[oaicite:2]{index=2}
    :contentReference[oaicite:3]{index=3}

# %% [markdown]
# How It Works
#  - Bernoulli PMF definition:
#
# f(k;p)={p/1−p if k=1, if k=0.
#
#
# That means if you observe a success (1), probability is p; else if failure (0), it’s 1 − p.
#
#  - The function checks k; if 1, returns p, if 0, returns 1 - p, otherwise raises an e

# %% [markdown]
# #### Optional: Using scipy.stats
# You can also use scipy.stats.bernoulli to do the same:

# %%
from scipy.stats import bernoulli

def bernoulli_pmf_scipy(k, p):
    return bernoulli(p).pmf(k)

# Example
:contentReference[oaicite:10]{index=10}
:contentReference[oaicite:11]{index=11}

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
#    -
#    Here's a Python script that simulates a Binomial Distribution with parameters n=10 and p=0.5, then plots its histogram using matplotlib and seaborn:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters
n = 10      # number of trials
p = 0.5     # probability of success
size = 1000  # number of simulations

# Generate binomial distributed data
data = np.random.binomial(n=n, p=p, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=range(n+2), kde=False, stat="probability", color='skyblue', edgecolor='black')

# Add labels and title
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.
#    -
#    Python Script: Poisson Distribution Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters
lambda_val = 4   # average rate (λ)
size = 1000      # number of samples

# Generate Poisson distributed data
data = np.random.poisson(lam=lambda_val, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=range(min(data), max(data)+2), kde=False, stat="probability", color='salmon', edgecolor='black')

# Add labels and title
plt.title(f'Poisson Distribution (λ={lambda_val})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete  uniform distribution.
#    -
#    Python Program: CDF of Discrete Uniform Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters of the discrete uniform distribution
low = 1
high = 6  # inclusive
values = np.arange(low, high + 1)

# Calculate the PMF (equal probabilities for each value)
pmf = np.ones_like(values) / len(values)

# Calculate the CDF
cdf = np.cumsum(pmf)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(values, cdf, where='mid', color='darkgreen', linewidth=2, label='CDF')
plt.scatter(values, cdf, color='black')

# Add labels and title
plt.title('CDF of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(values)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#  Explanation:
#
#  - A discrete uniform distribution assigns equal probability to each outcome in a finite set.
#  - Here, values from 1 to 6 (like a fair die) are used.
#  - The PMF is uniform, so the CDF is a steadily increasing step function.

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.
#    -
#    Python Program: Continuous Uniform Distribution Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters of the continuous uniform distribution
low = 0.0   # minimum value
high = 1.0  # maximum value
size = 1000  # number of samples

# Generate continuous uniform data
data = np.random.uniform(low=low, high=high, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=False, stat='density', color='skyblue', edgecolor='black')

# Plot theoretical PDF line
plt.hlines(y=1/(high - low), xmin=low, xmax=high, colors='red', linestyles='--', label='Theoretical PDF')

# Add labels and title
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Notes:
# np.random.uniform() generates continuous values in the range [low, high).
#
# The theoretical PDF of a continuous uniform distribution is constant:
#
# f(x)= 1/b−a for x∈[a,b]

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.
#    -
#    Python Program: Normal Distribution Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters for the normal distribution
mean = 0      # center of the distribution
std_dev = 1   # standard deviation
size = 1000   # number of samples

# Generate normally distributed data
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(data, bins=30, kde=True, color='lightcoral', edgecolor='black')

# Add labels and title
plt.title('Normal Distribution Histogram')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  What This Does:
#  - Simulates 1000 data points from a normal distribution with mean = 0 and std dev = 1.
#  - Uses Seaborn's kde=True to overlay the kernel density estimate (smooth curve)

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.
#    -
#    Here's a complete Python function that:
#
# Calculates Z-scores from a dataset.
#
# Plots the Z-scores on a line plot and histogram.

# %%
# Python Function: Calculate and Plot Z-scores

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_and_plot_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std

    # Plot Z-scores - Line Plot
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(z_scores, marker='o', linestyle='', color='blue')
    plt.axhline(y=0, color='black', linestyle='--')
    plt.title('Z-scores Line Plot')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.grid(True)

    # Plot Z-scores - Histogram
    plt.subplot(1, 2, 2)
    sns.histplot(z_scores, bins=30, kde=True, color='orange', edgecolor='black')
    plt.title('Z-scores Histogram')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.grid(True)

    plt.tight_layout()
    plt.show()
    return z_scores

# Example usage
np.random.seed(42)  # for reproducibility
data = np.random.normal(50, 10, 100)  # Sample data
z_scores = calculate_and_plot_z_scores(data)

# %% [markdown]
# What It Does:
#
# Z-score shows how many standard deviations a data point is from the mean.
#
# The line plot helps identify outliers.
#
# The histogram helps visualize the distribution of Z-scores (should be normal if the data is).

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
#     -
#     To demonstrate the Central Limit Theorem (CLT) using Python, we can:
#
# Draw samples from a non-normal distribution (e.g., exponential),
#
# Take the means of many random samples from it,
#
# Then visualize the distribution of these sample means, which will approximate a normal distribution.

# %%
#Python Implementation of CLT using Exponential Distribution

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set seed for reproducibility
np.random.seed(42)

# Parameters
population_size = 100000
sample_size = 30
num_samples = 1000

# Generate a non-normal (exponential) distribution
population = np.random.exponential(scale=2.0, size=population_size)

# Collect sample means
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Plot the original distribution
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(population, bins=50, kde=True, color='tomato', stat='density')
plt.title('Original Population (Exponential Distribution)')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot the distribution of sample means
plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='seagreen', stat='density')
plt.title(f'Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
#  Key Concepts:
#
#  - Exponential distribution is skewed, not normal.
#
#  - Sample means from this distribution approximate a normal distribution, even though the original is not.
#
#  - This demonstrates the Central Limit Theorem (CLT) in action.

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
#     -
#     Python Script: CLT Verification with Normal Distribution
#
# Although CLT is most powerful with non-normal data, this example confirms that even with normal data, the distribution of sample means becomes more concentrated and normal.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set seed for reproducibility
np.random.seed(42)

# Parameters
population_mean = 50
population_std = 10
sample_size = 30
num_samples = 1000

# Generate population from a normal distribution
population = np.random.normal(loc=population_mean, scale=population_std, size=100000)

# Generate sample means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Plot the original normal distribution
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(population, bins=50, kde=True, color='skyblue', stat='density')
plt.title('Original Normal Population')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot the distribution of sample means
plt.subplot(1, 2, 2)
sns.histplot(sample_means, bins=30, kde=True, color='lightgreen', stat='density')
plt.title(f'Distribution of Sample Means (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# What You’ll Observe:
#  - The left plot shows the original normal distribution.
#  - The right plot shows the distribution of sample means, which:
#    - Is normal.
#    - Has less spread (standard deviation = population_std / √sample_size).
#    - Centers around the population mean (≈50).

# %% [markdown]
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
#     -
#     Here's a Python function that:
#
#  - Calculates the standard normal distribution (mean = 0, std = 1),
#  - Plots its Probability Density Function (PDF) using scipy.stats.norm.

# %%
#Python Function: Standard Normal Distribution Plot

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    # Generate x values
    x = np.linspace(-4, 4, 500)
    
    # Calculate PDF of standard normal distribution
    y = norm.pdf(x, loc=0, scale=1)

    # Plot the PDF
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='darkblue', label='Standard Normal PDF')
    plt.fill_between(x, y, alpha=0.2, color='skyblue')
    
    # Add vertical lines at ±1, ±2, ±3 std deviations
    for z in [-3, -2, -1, 1, 2, 3]:
        plt.axvline(z, color='gray', linestyle='--', alpha=0.5)
        plt.text(z, 0.01, f'{z}σ', ha='center')

    # Title and labels
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# Notes:
#  - This visual includes Z-scores at ±1, ±2, ±3, highlighting the empirical rule (68–95–99.7 rule).
#  - scipy.stats.norm.pdf() computes the PDF for standard normal.

# %% [markdown]
# 13.  Generate random variables and calculate their corresponding probabilities using the binomial distribution.
#      -
#      Here's a Python script to:
#
# Generate random variables using the Binomial distribution,
#
# Calculate their corresponding probabilities (PMF).

# %%
# Python: Binomial Random Variables & Probabilities

import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters
n = 10         # number of trials
p = 0.5        # probability of success
size = 1000    # number of samples

# Generate random binomial variables
random_vars = np.random.binomial(n=n, p=p, size=size)

# Unique values and their frequencies
values, counts = np.unique(random_vars, return_counts=True)

# Normalize counts to get estimated probabilities
estimated_probs = counts / size

# Calculate theoretical probabilities (PMF)
theoretical_probs = binom.pmf(values, n, p)

# Plot both
plt.figure(figsize=(8, 5))
plt.bar(values - 0.2, estimated_probs, width=0.4, label='Estimated (Empirical)', color='skyblue', edgecolor='black')
plt.bar(values + 0.2, theoretical_probs, width=0.4, label='Theoretical PMF', color='orange', edgecolor='black')

# Labels and title
plt.title(f'Binomial Distribution: n={n}, p={p}')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(values)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  What This Script Does:
#  - Uses np.random.binomial() to simulate data.
#  - Uses scipy.stats.binom.pmf() to calculate theoretical binomial probabilities.
#  - Plots empirical vs theoretical probabilities side by side.

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
#     -
#     Here's a Python program that:
#
# Calculates the Z-score for a given data point,
#
# Plots the standard normal distribution,
#
# Marks the Z-score location visually on the distribution.

# %%
#Python Program: Z-score Calculation and Visualization

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    """Calculate Z-score for a data point."""
    z = (x - mean) / std
    return z

def plot_z_score(z):
    """Visualize the Z-score on the standard normal distribution."""
    x = np.linspace(-4, 4, 500)
    y = norm.pdf(x)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal PDF', color='darkblue')
    plt.fill_between(x, y, where=(x < z), color='skyblue', alpha=0.5, label='P(Z < z)')
    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
    
    plt.title('Z-score on Standard Normal Distribution')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Example usage
data_point = 75
population_mean = 70
population_std = 5

# Calculate Z-score
z = calculate_z_score(data_point, population_mean, population_std)
print(f"Z-score for x = {data_point}: {z:.2f}")

# Plot Z-score on standard normal distribution
plot_z_score(z)
# Out:
# Z-score for x = 75: 1.00

# %% [markdown]
# What It Shows:
#
# Z-score formula:
#
# Z= X−μ/σ
#
# Visually compares where a data point lies on the standard normal curve.

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.
#     -
#     Here's a Python implementation of hypothesis testing using Z-statistics, including:
#  - A sample dataset,
#  - Steps for a one-sample Z-test,
#  - Interpretation of results.
#
#  Scenario:
#  - You're testing if the average weight of a product differs from a claimed weight of μ₀ = 50 kg.
#  - You take a sample and want to test this claim at a 5% significance level (α = 0.05).

# %%
#Python Code: Z-Test Implementation

import numpy as np
from scipy.stats import norm

# Sample data (e.g., weights of items in kg)
sample_data = np.array([52, 49, 51, 50, 48, 53, 51, 50, 49, 52])

# Hypothesized population mean (μ₀)
mu_0 = 50

# Population standard deviation (σ) - known
population_std = 2

# Sample mean and size
sample_mean = np.mean(sample_data)
n = len(sample_data)

# Calculate Z-statistic
z_score = (sample_mean - mu_0) / (population_std / np.sqrt(n))

# Calculate p-value for two-tailed test
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Significance level
alpha = 0.05

# Print results
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-score = {z_score:.2f}")
print(f"P-value = {p_value:.4f}")

# Hypothesis testing decision
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference detected.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Sample Mean = 50.50
# Z-score = 0.79
# P-value = 0.4292
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
#  Hypothesis:
#  - Null (H₀): μ = 50 (no difference)
#  - Alternative (H₁): μ ≠ 50 (there is a difference).
#
#
# Assumptions:
#  - Population standard deviation is known.
#  - Sample size is not too small (Z-test appropriate).
#
#
# Let me know if you'd like to:
#  - Convert this to a one-tailed test,
#  - Use unknown σ with a T-test instead, or
#  - Plot the Z-distribution with shaded p-value!

# %% [markdown]
# 16.  Create a confidence interval for a dataset using Python and interpret the result.
#      -
#      Here's a Python example that:
#  - Calculates a confidence interval (CI) for a sample mean,
#  - Assumes population standard deviation is unknown (so it uses a t-distribution),
#  - Interprets the result.

# %%
# Python Code: Confidence Interval for a Sample Mean

import numpy as np
from scipy import stats

# Sample dataset (e.g., test scores, weights, etc.)
data = np.array([52, 49, 51, 50, 48, 53, 51, 50, 49, 52])

# Sample statistics
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # Standard Error of the Mean

# Confidence level (e.g., 95%)
confidence = 0.95

# Calculate t critical value
t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

# Margin of error
margin_of_error = t_critical * std_err

# Confidence Interval
ci_lower = mean - margin_of_error
ci_upper = mean + margin_of_error

# Output
print(f"Sample Mean = {mean:.2f}")
print(f"{int(confidence*100)}% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean = 50.50
# 95% Confidence Interval: (49.37, 51.63)

# %% [markdown]
# I|nterpretation:
# "We are 95% confident that the true population mean lies between CI_lower and CI_upper."
#
# This does not mean there's a 95% probability the mean is in this interval. Instead, if we repeat this sampling process many times, about 95% of the intervals we compute would contain the true mean.
#
#
# Let me know if you'd like to:
#  - Use a Z-distribution instead (if population std is known),
#  - Plot the CI visually over the sample distribution.

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
#     -
#     Here's how to:
#  - Generate random data from a normal distribution,
#  - Calculate a 95% confidence interval for the population mean,
#  - Interpret the result.

# %%
#Python Code: Normal Data + Confidence Interval

import numpy as np
from scipy import stats

# Step 1: Generate data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=50)  # mean=100, std=15, n=50

# Step 2: Sample statistics
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of the mean

# Step 3: Confidence level
confidence = 0.95
t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

# Step 4: Margin of error and CI
margin_of_error = t_critical * std_err
ci_lower = mean - margin_of_error
ci_upper = mean + margin_of_error

# Output
print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean = 96.62
# 95% Confidence Interval: (92.64, 100.60)

# %% [markdown]
# Interpretation:
#
# "We are 95% confident that the true mean of the population lies between ci_lower and ci_upper."
#
# This means: if you repeated this sampling process many times, 95% of the computed intervals would contain the actual mean.

# %% [markdown]
# 18.  Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
#      -
#      Here’s a Python script that:
#  - Calculates the Probability Density Function (PDF) of a normal distribution,
#  - Visualizes the PDF using matplotlib.

# %%
# Python Script: Normal Distribution PDF

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mean = 100
std_dev = 15

# Generate x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 500)

# Calculate PDF
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='blue', label=f'N({mean}, {std_dev}²)')
plt.fill_between(x, pdf, color='lightblue', alpha=0.4)
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#  Key Points:
#  - norm.pdf(x, loc=mean, scale=std_dev) computes the PDF values.
#  - The area under the curve sums to 1, as it represents a continuous probability distribution.

# %% [markdown]
# 19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
#      -
#      Here's how you can use Python to:
#  - Calculate the Cumulative Distribution Function (CDF) of a Poisson distribution,
#  - Visualize and interpret the results.

# %%
#Python Code: CDF of a Poisson Distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
mu = 4  # Average rate (λ) of events

# Define range of x values (discrete values)
x = np.arange(0, 15)

# Calculate CDF values
cdf_values = poisson.cdf(x, mu)

# Print a few CDF values
for xi, cdf in zip(x, cdf_values):
    print(f"P(X ≤ {xi}) = {cdf:.4f}")

# Plot CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', label=f'Poisson CDF (λ={mu})', color='purple')
plt.scatter(x, cdf_values, color='black')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('x (Number of Events)')
plt.ylabel('P(X ≤ x)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
#  Interpretation Example:
#  - If mu = 4, and P(X ≤ 6) = 0.8893, it means:
#  - “There is an 88.93% chance that the number of events will be 6 or fewer.”
#
#
# Let me know if you’d like to:
#  - Overlay the PMF (bar plot) for comparison,
#  - Change λ or use real-world event data.

# %% [markdown]
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.
#     -
#     Here’s how to:
#  - Simulate a random variable from a continuous uniform distribution,
#  - Calculate its expected value (mean) and compare it to the theoretical value.

# %%
 #Python Code: Continuous Uniform Distribution + Expected Value

import numpy as np

# Define the range of the uniform distribution
a = 10   # lower bound
b = 30   # upper bound

# Simulate random variable (generate 10000 samples)
np.random.seed(42)
samples = np.random.uniform(low=a, high=b, size=10000)

# Calculate expected value (sample mean)
sample_mean = np.mean(samples)

# Theoretical expected value for continuous uniform = (a + b) / 2
theoretical_mean = (a + b) / 2

# Output results
print(f"Sample Mean (Expected Value)     = {sample_mean:.2f}")
print(f"Theoretical Expected Value       = {theoretical_mean:.2f}")
# Out:
# Sample Mean (Expected Value)     = 19.88
# Theoretical Expected Value       = 20.00

# %% [markdown]
# Expected Value Interpretation:
#
# For a continuous uniform distribution
#
# U(a,b):
#
# Expected Value (E[X])= a+b/2
#
# So, in this example with a=10 and b=30,
#
# E[X]= 10+30/2=20
#
# The sample mean should be very close to 20 if the simulation is large enough (e.g., 10,000 samples).

# %% [markdown]
# 21.  Write a Python program to compare the standard deviations of two datasets and visualize the difference.
#      -
#      Here's a Python program that:
#  - Generates or uses two datasets,
#  - Calculates and compares their standard deviations,
#  - Visualizes the datasets using a histogram and a boxplot.

# %%
#Python Code: Compare Standard Deviations

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets
np.random.seed(0)
data1 = np.random.normal(loc=50, scale=5, size=1000)   # Smaller std dev
data2 = np.random.normal(loc=50, scale=15, size=1000)  # Larger std dev

# Step 2: Calculate standard deviations
std1 = np.std(data1)
std2 = np.std(data2)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Step 3: Visualize using histogram
plt.figure(figsize=(10, 5))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(data1, bins=30, alpha=0.6, label='Dataset 1 (low std)', color='blue')
plt.hist(data2, bins=30, alpha=0.6, label='Dataset 2 (high std)', color='orange')
plt.title('Histogram Comparison')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Boxplot
plt.subplot(1, 2, 2)
plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], patch_artist=True,
            boxprops=dict(facecolor='lightblue'), medianprops=dict(color='red'))
plt.title('Boxplot Comparison')
plt.ylabel('Value')

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.94
# Standard Deviation of Dataset 2: 14.52
# C:\Users\v\AppData\Local\Temp\ipykernel_10812\739061061.py:32: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], patch_artist=True,

# %% [markdown]
#  Interpretation:
#  - Standard deviation measures how spread out values are.
#  - Dataset 1 has less variability (tight spread), while Dataset 2 is more dispersed.
#  - The histogram and boxplot visually highlight this difference.

# %% [markdown]
# 22.  Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
#      -
#      Here's a Python program that:
#  - Generates data from a normal distribution,
#  - Calculates the Range and Interquartile Range (IQR),
#  - Outputs the values clearly.

# %%
# Python Code: Range & IQR Calculation

import numpy as np

# Step 1: Generate normal distribution data
np.random.seed(42)
data = np.random.normal(loc=100, scale=15, size=1000)  # mean=100, std=15

# Step 2: Calculate range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate IQR
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Output results
print(f"Data Range       = {data_range:.2f}")
print(f"1st Quartile (Q1)= {q1:.2f}")
print(f"3rd Quartile (Q3)= {q3:.2f}")
print(f"Interquartile Range (IQR) = {iqr:.2f}")
# Out:
# Data Range       = 106.41
# 1st Quartile (Q1)= 90.29
# 3rd Quartile (Q3)= 109.72
# Interquartile Range (IQR) = 19.43

# %% [markdown]
# Interpretation:
#  - Range = max − min → Total spread of the data.
#
#  - IQR = Q3 − Q1 → Spread of the middle 50% of the data.
#
# Helps detect outliers and measure data concentration.

# %% [markdown]
# 23.  Implement Z-score normalization on a dataset and visualize its transformation.
#      -
#      Here’s a complete Python program to:
#  - Generate a dataset,
#  - Apply Z-score normalization, and
#  - Visualize the original vs. normalized distributions using histograms.

# %%
#Python Code: Z-score Normalization and Visualization

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Step 1: Generate a dataset (e.g., from normal distribution)
np.random.seed(42)
data = np.random.normal(loc=100, scale=20, size=1000)

# Step 2: Z-score normalization
normalized_data = zscore(data)  # Equivalent to (x - mean) / std

# Step 3: Print summary
print(f"Original Mean: {np.mean(data):.2f}, Std Dev: {np.std(data):.2f}")
print(f"Normalized Mean: {np.mean(normalized_data):.2f}, Std Dev: {np.std(normalized_data):.2f}")

# Step 4: Visualization
plt.figure(figsize=(10, 5))

# Original data histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='steelblue', alpha=0.7)
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Normalized data histogram
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='orange', alpha=0.7)
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 100.39, Std Dev: 19.57
# Normalized Mean: -0.00, Std Dev: 1.00

# %% [markdown]
#  Z-score Formula:
#
# z= x−μ/σ
#
# Resulting data has mean ≈ 0 and standard deviation ≈ 1.
#
# Useful in standardizing datasets for comparison or ML preprocessing.

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal  distribution.
#     -
#     Here’s a Python function that:
#
# Generates a dataset from a normal distribution,
#
# Calculates skewness and kurtosis,
#
# Prints the interpretation.|

# %%
# Python Code: Skewness & Kurtosis Calculation

import numpy as np
from scipy.stats import skew, kurtosis

def analyze_normal_distribution_skew_kurtosis(mean=0, std=1, size=1000):
    # Generate data from a normal distribution
    np.random.seed(42)
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Calculate skewness and kurtosis
    skewness = skew(data)
    kurt = kurtosis(data)  # Default: Fisher’s definition (normal = 0)

    # Print results
    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis: {kurt:.4f}")

    # Interpretation
    if abs(skewness) < 0.5:
        print("→ Data is fairly symmetric.")
    elif skewness > 0:
        print("→ Data is positively skewed (right-tailed).")
    else:
        print("→ Data is negatively skewed (left-tailed).")

    if abs(kurt) < 1:
        print("→ Kurtosis is near normal (mesokurtic).")
    elif kurt > 0:
        print("→ Data has heavy tails (leptokurtic).")
    else:
        print("→ Data has light tails (platykurtic).")

# Call the function
analyze_normal_distribution_skew_kurtosis()
# Out:
# Skewness: 0.1168
# Kurtosis: 0.0662
# → Data is fairly symmetric.
# → Kurtosis is near normal (mesokurtic).

# %% [markdown]
#  What It Means:
#
# Skewness:
#
#  - 0 → symmetric
#  - > 0 → right-skewed
#  - < 0 → left-skewed
#
#
# Kurtosis (Fisher definition):
#
#  - 0 → normal tails (mesokurtic)
#  - > 0 → heavy tails (leptokurtic)
#  - < 0 → light tails (platykurtic)

# %% [markdown]
# ### Practical Part - 2

# %% [markdown]
# 1.  Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and  interpret the results.
#     -
#     Here's a Python program to:
#
# Perform a Z-test to compare a sample mean against a known population mean,
#
# Calculate the Z-score and corresponding p-value,
#
# Interpret the result using a significance level (α = 0.05).

# %%
# Python Code: One-Sample Z-Test

import numpy as np
from scipy.stats import norm

# Sample data (e.g., sample of test scores)
sample = np.array([102, 98, 100, 101, 99, 97, 103, 100, 98, 101])

# Step 1: Known population parameters
population_mean = 100
population_std = 2  # Known population standard deviation

# Step 2: Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Step 3: Z-test calculation
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Output and interpretation
print(f"Sample Mean        = {sample_mean:.2f}")
print(f"Population Mean    = {population_mean}")
print(f"Z-Score            = {z_score:.4f}")
print(f"P-Value            = {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("→ Reject the null hypothesis (significant difference).")
else:
    print("→ Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean        = 99.90
# Population Mean    = 100
# Z-Score            = -0.1581
# P-Value            = 0.8744
# → Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# Interpretation:
#
# Null Hypothesis (H₀): Sample mean = population mean
#
# Alternative Hypothesis (H₁): Sample mean ≠ population mean
#
# If p-value < 0.05, we reject H₀, indicating a significant difference.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
#    -
#    Here's a Python program that:
#  - Simulates random data from a known population,
#  - Performs hypothesis testing using a Z-test, and
#  - Calculates and interprets the p-value.

# %%
#Python Code: Simulated Hypothesis Testing with P-Value

import numpy as np
from scipy.stats import norm

# Step 1: Simulate random sample data
np.random.seed(42)
population_mean = 50
population_std = 10
sample_size = 40

# Simulate sample from a normal distribution
sample = np.random.normal(loc=52, scale=10, size=sample_size)  # Simulated sample mean ≠ population mean

# Step 2: Calculate sample mean
sample_mean = np.mean(sample)

# Step 3: Perform Z-test
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Print results
print(f"Sample Mean        = {sample_mean:.2f}")
print(f"Population Mean    = {population_mean}")
print(f"Z-Score            = {z_score:.4f}")
print(f"P-Value            = {p_value:.4f}")

# Step 5: Decision
alpha = 0.05
if p_value < alpha:
    print("→ Reject the null hypothesis (significant difference).")
else:
    print("→ Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean        = 49.81
# Population Mean    = 50
# Z-Score            = -0.1179
# P-Value            = 0.9062
# → Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# Interpretation:
#  - Null Hypothesis (H₀): Sample mean = Population mean
#  - Alternative Hypothesis (H₁): Sample mean ≠ Population mean
#  - P-value: Probability of observing such a result if H₀ is true
#  - If p < 0.05, we reject H₀ and conclude there's a statistically significant difference.

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
#    -
#    Here's a Python implementation of a one-sample Z-test to compare a sample mean with a known population mean.

# %%
#Python Code: One-Sample Z-Test

import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, population_mean, population_std, alpha=0.05):
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    
    # Z-test calculation
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

    # Print results
    print(f"Sample Mean       = {sample_mean:.2f}")
    print(f"Population Mean   = {population_mean}")
    print(f"Z-Score           = {z_score:.4f}")
    print(f"P-Value           = {p_value:.4f}")

    # Interpretation
    if p_value < alpha:
        print("→ Reject the null hypothesis (significant difference).")
    else:
        print("→ Fail to reject the null hypothesis (no significant difference).")

# Example usage
np.random.seed(0)
sample_data = np.random.normal(loc=105, scale=10, size=30)  # Sample from a distribution with mean ≠ population mean
population_mean = 100
population_std = 10  # Known population standard deviation

one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean       = 109.43
# Population Mean   = 100
# Z-Score           = 5.1642
# P-Value           = 0.0000
# → Reject the null hypothesis (significant difference).

# %% [markdown]
#  Key Notes:
#  - This is a two-tailed Z-test.
#  - Use when population standard deviation is known.
#  - For unknown population std, use a T-test instead.

# %% [markdown]
# 4.  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
#     -
#     Here's how to perform a two-tailed Z-test in Python and visualize the decision regions on the standard normal distribution.

# %%
#Python Code: Two-Tailed Z-Test with Visualization

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Simulate sample data
np.random.seed(42)
sample = np.random.normal(loc=102, scale=10, size=40)

# Known population parameters
population_mean = 100
population_std = 10
alpha = 0.05  # Significance level

# Step 2: Calculate sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Step 3: Calculate Z-score and P-value
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Print results
print(f"Sample Mean       = {sample_mean:.2f}")
print(f"Z-Score           = {z_score:.4f}")
print(f"P-Value           = {p_value:.4f}")

# Step 5: Determine critical Z values
z_critical = norm.ppf(1 - alpha / 2)

# Step 6: Plot standard normal curve with rejection regions
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label='Standard Normal Curve')
plt.axvline(-z_critical, color='red', linestyle='--', label=f'-Z Critical = {-z_critical:.2f}')
plt.axvline(z_critical, color='red', linestyle='--', label=f'+Z Critical = {z_critical:.2f}')
plt.axvline(z_score, color='blue', linestyle='-', label=f'Z Score = {z_score:.2f}')
plt.fill_between(x, y, 0, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3)

plt.title('Two-Tailed Z-Test: Decision Regions')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Step 7: Interpretation
if abs(z_score) > z_critical:
    print("→ Reject the null hypothesis (Z falls in the rejection region).")
else:
    print("→ Fail to reject the null hypothesis (Z falls in the acceptance region).")
# Out:
# Sample Mean       = 99.81
# Z-Score           = -0.1179
# P-Value           = 0.9062
# → Fail to reject the null hypothesis (Z falls in the acceptance region).

# %% [markdown]
#  What’s Shown in the Plot:
#  - Red shaded areas: Rejection regions (α/2 on each tail).
#  - Z critical values: Thresholds beyond which we reject H₀.
#  - Your Z-score: Shown as a blue vertical line.

# %% [markdown]
# 5.  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
#     -
#     Great! Here's a Python function that:
#
# Simulates hypothesis testing for a normal distribution,
#
# Calculates Type I error (α) and Type II error (β),
#
# Visualizes both errors with the decision boundary.

# %%
#Python Code: Type I and Type II Error Visualization

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu_0=100, mu_1=105, sigma=10, n=30, alpha=0.05):
    """
    mu_0: population mean under null hypothesis
    mu_1: actual mean under alternative hypothesis
    sigma: population standard deviation
    n: sample size
    alpha: significance level (Type I error rate)
    """
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value for a one-tailed test (right-tailed)
    z_crit = norm.ppf(1 - alpha)
    x_crit = mu_0 + z_crit * se

    # Type I Error region (alpha)
    x = np.linspace(mu_0 - 4*se, mu_1 + 4*se, 1000)
    y_null = norm.pdf(x, mu_0, se)
    y_alt = norm.pdf(x, mu_1, se)

    # Type II error: P(failing to reject H0 when H1 is true)
    beta = norm.cdf((x_crit - mu_1) / se)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(x, y_null, label='H₀: μ = {}'.format(mu_0), color='blue')
    plt.plot(x, y_alt, label='H₁: μ = {}'.format(mu_1), color='green')

    # Shade Type I error (right tail of H0)
    plt.fill_between(x, y_null, 0, where=(x >= x_crit), color='red', alpha=0.4, label='Type I Error (α)')

    # Shade Type II error (left of x_crit under H1)
    plt.fill_between(x, y_alt, 0, where=(x < x_crit), color='orange', alpha=0.4, label='Type II Error (β)')

    plt.axvline(x_crit, color='black', linestyle='--', label=f'Critical Value = {x_crit:.2f}')
    plt.title("Type I and Type II Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Critical Value: {x_crit:.2f}")
    print(f"Type I Error (α): {alpha}")
    print(f"Type II Error (β): {beta:.4f}")
    print(f"Power of the test (1 - β): {1 - beta:.4f}")

# Run the function
visualize_type1_type2_errors()
# Out:
# Critical Value: 103.00
# Type I Error (α): 0.05
# Type II Error (β): 0.1370
# Power of the test (1 - β): 0.8630

# %% [markdown]
#  Explanation:
#  - H₀ (null): The assumed population mean (mu_0)
#  - H₁ (alternative): The actual/true mean (mu_1)
#  - Type I Error (α): Rejecting H₀ when it’s true — red region
#  - Type II Error (β): Failing to reject H₀ when H₁ is true — orange region
#  - Power: Probability of correctly rejecting H₀ (1 − β)

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.
#    -
#    Here's a Python program to perform an independent two-sample T-test, which is used to compare the means of two independent groups, and includes interpretation.

# %%
#Python Code: Independent T-Test with Interpretation

import numpy as np
from scipy.stats import ttest_ind

# Step 1: Simulate data for two independent groups
np.random.seed(42)
group1 = np.random.normal(loc=100, scale=10, size=30)
group2 = np.random.normal(loc=105, scale=10, size=30)

# Step 2: Perform independent two-sample T-test
t_stat, p_value = ttest_ind(group1, group2)

# Step 3: Print results
print("Group 1 Mean:", np.mean(group1))
print("Group 2 Mean:", np.mean(group2))
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Step 4: Interpret results
alpha = 0.05
if p_value < alpha:
    print("→ Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("→ Fail to reject the null hypothesis: No significant difference between the groups.")
# Out:
# Group 1 Mean: 98.11853104148962
# Group 2 Mean: 103.78837529710059
# T-Statistic: -2.3981
# P-Value: 0.0197
# → Reject the null hypothesis: There is a significant difference between the groups.

# %% [markdown]
# Key Concepts:
#
# Null Hypothesis (H₀): μ₁ = μ₂ (no difference)
#
# Alternative Hypothesis (H₁): μ₁ ≠ μ₂ (means are different)
#
# Use T-test when population standard deviations are unknown and sample sizes are small or comparable.

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results.
#    -
#    Here's how to perform a paired sample T-test in Python and visualize the before-and-after comparison of two related samples (e.g., test scores before and after training).

# %%
#Python Code: Paired Sample T-Test with Visualization

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Step 1: Simulate related (paired) sample data
np.random.seed(42)
before = np.random.normal(loc=70, scale=8, size=30)      # e.g., pre-treatment scores
after = before + np.random.normal(loc=5, scale=5, size=30)  # e.g., post-treatment scores

# Step 2: Paired Sample T-test
t_stat, p_value = ttest_rel(before, after)

# Step 3: Print results
print("Mean Before:", np.mean(before))
print("Mean After :", np.mean(after))
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value    : {p_value:.4f}")

# Step 4: Interpret results
alpha = 0.05
if p_value < alpha:
    print("→ Reject the null hypothesis: There is a significant change.")
else:
    print("→ Fail to reject the null hypothesis: No significant change.")

# Step 5: Visualization
plt.figure(figsize=(10, 5))
plt.plot(before, label='Before', marker='o')
plt.plot(after, label='After', marker='o')
plt.title("Paired Sample Data Comparison")
plt.xlabel("Sample Index")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Before: 68.4948248331917
# Mean After : 72.88901248174199
# T-Statistic: -5.1698
# P-Value    : 0.0000
# → Reject the null hypothesis: There is a significant change.

# %% [markdown]
# Interpretation:
#
# Paired T-Test checks if the mean difference between two related groups is significantly different from zero.
#
# Use when observations are dependent (e.g., same participants measured twice).
#
# Null Hypothesis (H₀): Mean difference = 0
#
# Alternative Hypothesis (H₁): Mean difference ≠ 0

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.
#    -
#    Here's a complete Python program to:
#  - Simulate data from a normal distribution,
#  - Perform both Z-test and T-test on the same sample, and
#  - Compare the results (Z-statistic vs T-statistic, and p-values).

# %%
#Python Code: Z-Test vs T-Test Comparison

import numpy as np
from scipy.stats import norm, t

# Step 1: Simulate sample data
np.random.seed(42)
sample_size = 25
population_mean = 100
population_std = 15  # Known for Z-test
sample = np.random.normal(loc=102, scale=15, size=sample_size)

# Step 2: Sample statistics
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)  # Sample std for T-test
se_z = population_std / np.sqrt(sample_size)
se_t = sample_std / np.sqrt(sample_size)

# Step 3: Z-test (uses known population std dev)
z_score = (sample_mean - population_mean) / se_z
z_p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed

# Step 4: T-test (uses sample std dev)
t_score = (sample_mean - population_mean) / se_t
t_p_value = 2 * (1 - t.cdf(abs(t_score), df=sample_size - 1))

# Step 5: Output results
print("Sample Mean:", round(sample_mean, 2))
print("Sample Std Dev:", round(sample_std, 2))
print("Sample Size:", sample_size)
print("Population Mean:", population_mean)
print("\n--- Z-Test Results ---")
print(f"Z-Score  = {z_score:.4f}")
print(f"P-Value  = {z_p_value:.4f}")
print("\n--- T-Test Results ---")
print(f"T-Score  = {t_score:.4f}")
print(f"P-Value  = {t_p_value:.4f}")

# Step 6: Conclusion
alpha = 0.05
print("\n--- Interpretation ---")
if z_p_value < alpha:
    print("Z-Test: Reject the null hypothesis.")
else:
    print("Z-Test: Fail to reject the null hypothesis.")

if t_p_value < alpha:
    print("T-Test: Reject the null hypothesis.")
else:
    print("T-Test: Fail to reject the null hypothesis.")
# Out:
# Sample Mean: 99.55
# Sample Std Dev: 14.35
# Sample Size: 25
# Population Mean: 100
#
# --- Z-Test Results ---
# Z-Score  = -0.1509
# P-Value  = 0.8801
#
# --- T-Test Results ---
# T-Score  = -0.1577
# P-Value  = 0.8760
#
# --- Interpretation ---
# Z-Test: Fail to reject the null hypothesis.
# T-Test: Fail to reject the null hypothesis.

# %% [markdown]
#  What This Shows:
#
# Z-Test assumes known population standard deviation.
#
# T-Test is more realistic when population std is unknown.
#
# For small samples (n < 30), T-test is more conservative (i.e., slightly wider tails).
#
# You might notice:
#
# T-score ≈ Z-score, but
#
# T p-value > Z p-value due to smaller degrees of freedom.

# %% [markdown]
# 9.  Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
#     -
#     Python Function: Confidence Interval for Sample Mean

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    """
    Calculate confidence interval for a sample mean.
    
    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (default = 0.95 for 95%)

    Returns:
        Tuple: (lower bound, upper bound)
    """
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    t_crit = t.ppf((1 + confidence) / 2, df=n - 1)

    margin_of_error = t_crit * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return (lower_bound, upper_bound), mean, margin_of_error

# Example usage:
np.random.seed(42)
sample_data = np.random.normal(loc=100, scale=15, size=30)

(ci_low, ci_high), mean, margin = confidence_interval(sample_data)
print(f"Sample Mean          = {mean:.2f}")
print(f"95% Confidence Interval = ({ci_low:.2f}, {ci_high:.2f})")
print(f"Margin of Error      = ±{margin:.2f}")
# Out:
# Sample Mean          = 97.18
# 95% Confidence Interval = (92.14, 102.22)
# Margin of Error      = ±5.04

# %% [markdown]
# Significance of a Confidence Interval:
#  - A confidence interval gives a range of values within which the true population mean is likely to fall.
#  - A 95% CI means that if we took 100 different samples and built a CI from each, about 95 of them would contain the true population mean.
#  - It provides both:
#    - Estimate: Sample mean
#    - Uncertainty: Margin of error

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.
#     -
#     Python Program: Margin of Error Calculation

# %%
import numpy as np
from scipy.stats import t

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a sample mean.
    
    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (default = 0.95 for 95%)

    Returns:
        float: Margin of error
    """
    n = len(data)
    std_dev = np.std(data, ddof=1)
    std_err = std_dev / np.sqrt(n)

    # Get t-critical value
    t_crit = t.ppf((1 + confidence) / 2, df=n - 1)
    
    # Margin of error
    moe = t_crit * std_err
    return moe

# Example usage:
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=25)

moe = calculate_margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error (95% confidence): ±{moe:.2f}")
# Out:
# Margin of Error (95% confidence): ±3.95

# %% [markdown]
# Explanation:
#  - Margin of Error (MOE) quantifies the range within which the true population mean is likely to lie.
#  - It depends on:
#    - Confidence level (higher confidence = wider margin),
#    - Sample size (larger n = smaller margin),
#    - Variability in the sample (higher standard deviation = larger margin).

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
#     -
#     Bayes’ Theorem
#
#                   P(H∣D)= P(D∣H)⋅P(H)/P(D)
#
# Where:
#
# P(H∣D): Posterior (probability of hypothesis H given data D)
#
# P(H): Prior (belief about H before seeing data)
#
# P(D∣H): Likelihood (probability of data under hypothesis)
#
# P(D): Marginal likelihood (normalizing constant)
#
#
# Scenario:
#  - You take a test for a rare disease:
#  - Disease prevalence (prior) = 1%
#  - Test sensitivity (true positive rate) = 99%
#  - Test specificity (true negative rate) = 95%
#  - You tested positive. What’s the probability you actually have the disease?

# %%
def bayes_theorem(prior, sensitivity, specificity):
    """
    Calculates posterior probability using Bayes' Theorem.
    
    prior: P(Disease) - prior probability of having the disease
    sensitivity: P(Pos|Disease) - true positive rate
    specificity: P(Neg|No Disease) - true negative rate
    """
    # P(Pos|No Disease)
    false_positive_rate = 1 - specificity
    
    # P(Disease|Pos) = [P(Pos|Disease) * P(Disease)] / P(Pos)
    numerator = sensitivity * prior
    denominator = (sensitivity * prior) + (false_positive_rate * (1 - prior))
    posterior = numerator / denominator
    return posterior

# Parameters
prior = 0.01           # 1% disease prevalence
sensitivity = 0.99     # 99% test sensitivity
specificity = 0.95     # 95% test specificity

# Compute posterior
posterior = bayes_theorem(prior, sensitivity, specificity)
print(f"Probability of having the disease after testing positive: {posterior:.4f} ({posterior*100:.2f}%)")
# Out:
# Probability of having the disease after testing positive: 0.1667 (16.67%)

# %% [markdown]
# Explanation:
#  - Prior: 1% of the population has the disease.
#  - Likelihood: If you have the disease, the test detects it 99% of the time.
#  - False Positive Rate: 5% of healthy people test positive.
#  - Posterior: After testing positive, there's still only ~17% chance you actually have the disease — due to the low prior and non-negligible false positives.

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python.
#     -
#     Chi-Square Test for Independence in Python
#
# Scenario:
#
# You want to test whether gender and preference for a product are independent.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create a contingency table
# Example: Gender vs Product Preference
#              Like   Neutral  Dislike
# Male          20      15       10
# Female        30      25       15

data = np.array([[20, 15, 10],
                 [30, 25, 15]])

# Optional: convert to DataFrame for readability
df = pd.DataFrame(data, 
                  columns=['Like', 'Neutral', 'Dislike'],
                  index=['Male', 'Female'])

print("Contingency Table:")
print(df)

# Step 2: Perform Chi-Square Test
chi2, p, dof, expected = chi2_contingency(data)

# Step 3: Output results
print("\nChi-Square Statistic:", round(chi2, 4))
print("Degrees of Freedom   :", dof)
print("P-Value              :", round(p, 4))
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, columns=df.columns, index=df.index))

# Step 4: Interpretation
alpha = 0.05
if p < alpha:
    print("\n→ Reject the null hypothesis: There is a significant association between gender and product preference.")
else:
    print("\n→ Fail to reject the null hypothesis: No significant association found between gender and product preference.")
# Out:
# Contingency Table:
#         Like  Neutral  Dislike
# Male      20       15       10
# Female    30       25       15
#
# Chi-Square Statistic: 0.0685
# Degrees of Freedom   : 2
# P-Value              : 0.9664
#
# Expected Frequencies:
#              Like    Neutral    Dislike
# Male    19.565217  15.652174   9.782609
# Female  30.434783  24.347826  15.217391
#
# → Fail to reject the null hypothesis: No significant association found between gender and product preference.

# %% [markdown]
#  Key Concepts:
#  - Null Hypothesis (H₀): Variables are independent (no association).
#  - Alternative Hypothesis (H₁): There is an association.
#  - Use for analyzing two categorical variables (e.g., survey responses, gender vs outcome, etc.)

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed  data.
#     -
#     Python Program: Expected Frequencies for Chi-Square Test

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Input observed data (contingency table)
# Example: Survey of preferences between gender and drink choice
#            Coffee  Tea
#   Male       40     20
#   Female     30     50

observed = np.array([[40, 20],
                     [30, 50]])

# Optional: Create a labeled DataFrame for readability
df = pd.DataFrame(observed, columns=["Coffee", "Tea"], index=["Male", "Female"])
print("Observed Frequencies:\n", df)

# Step 2: Compute expected frequencies using chi2_contingency
chi2, p, dof, expected = chi2_contingency(observed)

# Step 3: Show expected frequencies
expected_df = pd.DataFrame(expected, columns=["Coffee", "Tea"], index=["Male", "Female"])
print("\nExpected Frequencies:\n", expected_df.round(2))
# Out:
# Observed Frequencies:
#          Coffee  Tea
# Male        40   20
# Female      30   50
#
# Expected Frequencies:
#          Coffee   Tea
# Male      30.0  30.0
# Female    40.0  40.0

# %% [markdown]
# What Are Expected Frequencies?
#  - The frequencies we expect to see if the two categorical variables were independent.
#  - Calculated as:
#
#                  Eij = Row totali * Column totalj / Grand total

# %% [markdown]
# 14.  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
#      -
#      Scenario:
#
# You're rolling a 6-sided die 60 times and observing the outcomes. You want to test if the die is fair (i.e., all outcomes equally likely).

# %%
#Python Code: Chi-square Goodness-of-Fit Test

import numpy as np
from scipy.stats import chisquare

# Step 1: Observed frequencies (from rolling a die 60 times)
observed = np.array([8, 9, 10, 12, 11, 10])  # total = 60

# Step 2: Expected frequencies for a fair die (uniform distribution)
expected = np.full_like(observed, fill_value=60/6)

# Step 3: Perform Chi-square goodness-of-fit test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 4: Display results
print("Observed Frequencies:", observed)
print("Expected Frequencies:", expected)
print(f"\nChi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpretation
alpha = 0.05
if p_value < alpha:
    print("→ Reject the null hypothesis: The die is not fair.")
else:
    print("→ Fail to reject the null hypothesis: No evidence the die is unfair.")
# Out:
# Observed Frequencies: [ 8  9 10 12 11 10]
# Expected Frequencies: [10 10 10 10 10 10]
#
# Chi-square Statistic: 1.0000
# P-value: 0.9626
# → Fail to reject the null hypothesis: No evidence the die is unfair.

# %% [markdown]
#  Goodness-of-Fit Test Recap:
#  - Purpose: Test if observed data fits a theoretical distribution.
#  - Null Hypothesis (H₀): Observed frequencies match the expected distribution.
#  - Alternative Hypothesis (H₁): Observed frequencies differ significantly.
#  - Use: Coin/dice fairness, population proportions, genetics models, etc.

# %% [markdown]
# ## COMPLETE
